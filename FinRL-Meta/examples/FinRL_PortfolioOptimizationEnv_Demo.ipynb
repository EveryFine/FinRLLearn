# %% [markdown]
# # A guide Portfolio Optimization Environment

# %% [markdown]
# This notebook aims to provide an example of using PortfolioOptimizationEnv (or POE) to train a reinforcement learning model that learns to solve the portfolio optimization problem.
#
# In this document, we will reproduce a famous architecture called EIIE (ensemble of identical independent evaluators), introduced in the following paper:
#
# - Zhengyao Jiang, Dixing Xu, & Jinjun Liang. (2017). A Deep Reinforcement Learning Framework for the Financial Portfolio Management Problem. https://doi.org/10.48550/arXiv.1706.10059.
#
# It's advisable to read it to understand the algorithm implemented in this notebook.
#
# ### Note
# If you're using this environment, consider citing the following paper (in adittion to FinRL references):
#
# - Caio Costa, & Anna Costa (2023). POE: A General Portfolio Optimization Environment for FinRL. In *Anais do II Brazilian Workshop on Artificial Intelligence in Finance* (pp. 132–143). SBC. https://doi.org/10.5753/bwaif.2023.231144.
#
# ```
# @inproceedings{bwaif,
#  author = {Caio Costa and Anna Costa},
#  title = {POE: A General Portfolio Optimization Environment for FinRL},
#  booktitle = {Anais do II Brazilian Workshop on Artificial Intelligence in Finance},
#  location = {João Pessoa/PB},
#  year = {2023},
#  keywords = {},
#  issn = {0000-0000},
#  pages = {132--143},
#  publisher = {SBC},
#  address = {Porto Alegre, RS, Brasil},
#  doi = {10.5753/bwaif.2023.231144},
#  url = {https://sol.sbc.org.br/index.php/bwaif/article/view/24959}
# }
#
# ```

# %% [markdown]
# ## Installation and imports

# %%
# !pip install swig
# !pip install wrds

# %%
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to /private/var/folders/dv/ly5hp_ms3bd9753868lg6c5w0000gn/T/pip-req-build-o6qy9ypa
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git /private/var/folders/dv/ly5hp_ms3bd9753868lg6c5w0000gn/T/pip-req-build-o6qy9ypa
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit 0496601ee2824ca675beb5a220afd9109ac02ffa
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl (from finrl==0.3.6)
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /private/var/folders/dv/ly5hp_ms3bd9753868lg6c5w0000gn/T/pip-install-kj9x1vzr/elegantrl_5452621d997a4daca0375cefae6f3a35
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /private/var/folders/dv/ly5hp_ms3bd9753868lg6c5w0000gn/T/pip-install-kj9x1vzr/elegantrl_5452621d997a4daca0375cefae6f3a35
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 5bca7aeeb73f5779788dd6714a53b59ce880c583
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: alpaca-trade-api<4,>=3 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from finrl==0.3.6) (3.2.0)
# Collecting ccxt<4,>=3 (from finrl==0.3.6)
#   Obtaining dependency information for ccxt<4,>=3 from https://files.pythonhosted.org/packages/c6/c3/5082649cf584dae9ee18d7d90895475e8f382b52e9c8588320f477639e04/ccxt-3.1.60-py2.py3-none-any.whl.metadata
#   Using cached ccxt-3.1.60-py2.py3-none-any.whl.metadata (108 kB)
# Collecting exchange-calendars<5,>=4 (from finrl==0.3.6)
#   Obtaining dependency information for exchange-calendars<5,>=4 from https://files.pythonhosted.org/packages/82/15/2c7bf8ac0f044105f55ebbf33f509f94cdc2ecaf4d78d3eced4af64e7f1f/exchange_calendars-4.5.8-py3-none-any.whl.metadata
#   Downloading exchange_calendars-4.5.8-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: jqdatasdk<2,>=1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from finrl==0.3.6) (1.9.6)
# Requirement already satisfied: pyfolio<0.10,>=0.9 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from finrl==0.3.6) (0.9.2)
# Collecting pyportfolioopt<2,>=1 (from finrl==0.3.6)
#   Obtaining dependency information for pyportfolioopt<2,>=1 from https://files.pythonhosted.org/packages/e3/7d/4930adde3743e4d3bf4e30a19af14c3d9f622e8e7b4e6bb7dfb68f98ce8f/pyportfolioopt-1.5.5-py3-none-any.whl.metadata
#   Using cached pyportfolioopt-1.5.5-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: ray[default,tune]<3,>=2 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from finrl==0.3.6) (2.39.0)
# Requirement already satisfied: scikit-learn<2,>=1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from finrl==0.3.6) (1.5.2)
# Requirement already satisfied: stable-baselines3[extra]>=2.0.0a5 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from finrl==0.3.6) (2.3.2)
# Collecting stockstats<0.6,>=0.5 (from finrl==0.3.6)
#   Obtaining dependency information for stockstats<0.6,>=0.5 from https://files.pythonhosted.org/packages/89/c3/82708cf1d219d762d6bb1a05428d918ad3f68c26b7f6e10a7449942a12c8/stockstats-0.5.4-py2.py3-none-any.whl.metadata
#   Using cached stockstats-0.5.4-py2.py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: wrds<4,>=3 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from finrl==0.3.6) (3.2.0)
# Requirement already satisfied: yfinance<0.3,>=0.2 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from finrl==0.3.6) (0.2.49)
# Requirement already satisfied: pandas>=0.18.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.2.3)
# Requirement already satisfied: numpy>=1.11.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.26.4)
# Requirement already satisfied: requests<3,>2 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.32.3)
# Requirement already satisfied: urllib3<2,>1.24 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.26.20)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.8.0)
# Requirement already satisfied: websockets<11,>=9.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (10.4)
# Requirement already satisfied: msgpack==1.0.3 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.0.3)
# Requirement already satisfied: aiohttp<4,>=3.8.3 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (3.10.11)
# Requirement already satisfied: PyYAML==6.0.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (6.0.1)
# Requirement already satisfied: deprecation==2.1.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.1.0)
# Requirement already satisfied: packaging in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl==0.3.6) (23.2)
# Requirement already satisfied: setuptools>=60.9.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.6) (68.2.0)
# Requirement already satisfied: certifi>=2018.1.18 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.6) (2024.8.30)
# Requirement already satisfied: cryptography>=2.6.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.6) (43.0.3)
# Requirement already satisfied: aiodns>=1.1.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.6) (3.2.0)
# Requirement already satisfied: yarl>=1.7.2 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.6) (1.17.1)
# Requirement already satisfied: pyluach in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2.2.0)
# Requirement already satisfied: toolz in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (1.0.0)
# Requirement already satisfied: tzdata in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2024.2)
# Requirement already satisfied: korean-lunar-calendar in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (0.3.1)
# Requirement already satisfied: six in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.16.0)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (2.0.36)
# Requirement already satisfied: pymysql>=0.7.6 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.1.1)
# Requirement already satisfied: thriftpy2!=0.5.1,>=0.3.9 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (0.5.2)
# Requirement already satisfied: ipython>=3.2.3 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (8.29.0)
# Requirement already satisfied: matplotlib>=1.4.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (3.9.2)
# Requirement already satisfied: pytz>=2014.10 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (2024.2)
# Requirement already satisfied: scipy>=0.14.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (1.12.0)
# Requirement already satisfied: seaborn>=0.7.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (0.13.2)
# Requirement already satisfied: empyrical>=0.5.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (0.5.5)
# Collecting cvxpy<2.0.0,>=1.1.19 (from pyportfolioopt<2,>=1->finrl==0.3.6)
#   Obtaining dependency information for cvxpy<2.0.0,>=1.1.19 from https://files.pythonhosted.org/packages/fb/6d/000d81398eec413c21c36077ffceeeae6ac36ebf698070555a074459c6e2/cvxpy-1.6.0-cp310-cp310-macosx_10_9_universal2.whl.metadata
#   Downloading cvxpy-1.6.0-cp310-cp310-macosx_10_9_universal2.whl.metadata (9.2 kB)
# Requirement already satisfied: click>=7.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (8.1.7)
# Requirement already satisfied: filelock in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (3.16.1)
# Requirement already satisfied: jsonschema in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (4.23.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (5.28.3)
# Requirement already satisfied: aiosignal in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.3.1)
# Requirement already satisfied: frozenlist in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.5.0)
# Requirement already satisfied: tensorboardX>=1.9 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (2.6.2.2)
# Requirement already satisfied: pyarrow>=6.0.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (18.0.0)
# Requirement already satisfied: fsspec in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (2024.10.0)
# Requirement already satisfied: aiohttp-cors in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.7.0)
# Requirement already satisfied: colorful in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.5.6)
# Requirement already satisfied: py-spy>=0.2.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.4.0)
# Requirement already satisfied: opencensus in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.11.4)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (2.9.2)
# Requirement already satisfied: prometheus-client>=0.7.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.21.0)
# Requirement already satisfied: smart-open in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (7.0.5)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (20.27.1)
# Requirement already satisfied: grpcio>=1.42.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.68.0)
# Requirement already satisfied: memray in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.14.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from scikit-learn<2,>=1->finrl==0.3.6) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from scikit-learn<2,>=1->finrl==0.3.6) (3.5.0)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.29.1)
# Requirement already satisfied: torch>=1.13 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.5.1)
# Requirement already satisfied: cloudpickle in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.1.0)
# Requirement already satisfied: opencv-python in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.10.0.84)
# Requirement already satisfied: pygame in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.1.0)
# Requirement already satisfied: tensorboard>=2.9.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.18.0)
# Requirement already satisfied: psutil in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (6.1.0)
# Requirement already satisfied: tqdm in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.67.0)
# Requirement already satisfied: rich in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (13.9.4)
# Requirement already satisfied: shimmy[atari]~=1.3.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.3.0)
# Requirement already satisfied: pillow in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (11.0.0)
# Requirement already satisfied: autorom[accept-rom-license]~=0.6.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.6.1)
# Requirement already satisfied: psycopg2-binary<2.10,>=2.9 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from wrds<4,>=3->finrl==0.3.6) (2.9.10)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (4.3.6)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (3.17.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (1.1)
# Collecting th (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6)
#   Obtaining dependency information for th from https://files.pythonhosted.org/packages/2f/29/969d96eeb98abf22915ce59079ac77e0e7d1cdcf5750aa0b46e4b057233f/th-0.4.1-py3-none-any.whl.metadata
#   Using cached th-0.4.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: pycares>=4.0.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from aiodns>=1.1.1->ccxt<4,>=3->finrl==0.3.6) (4.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.6) (2.4.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.6) (24.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.6) (6.1.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.6) (5.0.1)
# Requirement already satisfied: AutoROM.accept-rom-license in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.6.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance<0.3,>=0.2->finrl==0.3.6) (2.6)
# Requirement already satisfied: cffi>=1.12 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6) (1.17.1)
# Collecting osqp>=0.6.2 (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6)
#   Obtaining dependency information for osqp>=0.6.2 from https://files.pythonhosted.org/packages/d6/4d/99baf07fe2ef99c0ccca4c936bcf86911ac1e01274ed932ffbe1d3ef1b13/osqp-0.6.7.post3-cp310-cp310-macosx_11_0_arm64.whl.metadata
#   Using cached osqp-0.6.7.post3-cp310-cp310-macosx_11_0_arm64.whl.metadata (1.9 kB)
# Collecting clarabel>=0.5.0 (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6)
#   Obtaining dependency information for clarabel>=0.5.0 from https://files.pythonhosted.org/packages/8b/b9/e41f5316a2d4261c340d9fa6aa1694dd57d12cc45f1e5dfc5773d2b53d39/clarabel-0.9.0-cp37-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata
#   Using cached clarabel-0.9.0-cp37-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (4.8 kB)
# Collecting scs>=3.2.4.post1 (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6)
#   Obtaining dependency information for scs>=3.2.4.post1 from https://files.pythonhosted.org/packages/8d/ca/b7c16fb48159e7f209d517b3381cc8174f2e2896fb75095fd63e9935c995/scs-3.2.7-cp310-cp310-macosx_11_0_arm64.whl.metadata
#   Using cached scs-3.2.7-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: pandas-datareader>=0.2 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from empyrical>=0.5.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.0.4)
# Requirement already satisfied: webencodings in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from html5lib>=1.1->yfinance<0.3,>=0.2->finrl==0.3.6) (0.5.1)
# Requirement already satisfied: decorator in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.18.0)
# Requirement already satisfied: stack-data in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (5.14.3)
# Requirement already satisfied: exceptiongroup in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.9.0.post0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[default,tune]<3,>=2->finrl==0.3.6) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[default,tune]<3,>=2->finrl==0.3.6) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from requests<3,>2->alpaca-trade-api<4,>=3->finrl==0.3.6) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from requests<3,>2->alpaca-trade-api<4,>=3->finrl==0.3.6) (3.10)
# Requirement already satisfied: ale-py~=0.8.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from shimmy[atari]~=1.3.0->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.8.1)
# Requirement already satisfied: absl-py>=0.4 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.1.3)
# Requirement already satisfied: Cython>=3.0.10 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from thriftpy2!=0.5.1,>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.6) (3.0.11)
# Requirement already satisfied: ply<4.0,>=3.4 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from thriftpy2!=0.5.1,>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.6) (3.11)
# Requirement already satisfied: networkx in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from sympy==1.13.1->torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.3.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.6) (0.3.9)
# Requirement already satisfied: propcache>=0.2.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from yarl>=1.7.2->ccxt<4,>=3->finrl==0.3.6) (0.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from jsonschema->ray[default,tune]<3,>=2->finrl==0.3.6) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from jsonschema->ray[default,tune]<3,>=2->finrl==0.3.6) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from jsonschema->ray[default,tune]<3,>=2->finrl==0.3.6) (0.21.0)
# Requirement already satisfied: textual>=0.41.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from memray->ray[default,tune]<3,>=2->finrl==0.3.6) (0.86.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.0.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (2.23.0)
# Requirement already satisfied: wrapt in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from smart-open->ray[default,tune]<3,>=2->finrl==0.3.6) (1.16.0)
# Collecting niltype<2.0,>=0.3 (from th->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6)
#   Obtaining dependency information for niltype<2.0,>=0.3 from https://files.pythonhosted.org/packages/41/d2/d3dee14b063ce2ce641a5f6d40b3537622373678c9db9ccbe67d15029b13/niltype-1.0.2-py3-none-any.whl.metadata
#   Using cached niltype-1.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: importlib-resources in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (6.4.5)
# Requirement already satisfied: pycparser in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6) (2.22)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (1.66.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (1.25.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (2.36.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from jinja2->torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.0.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.1.2)
# Collecting qdldl (from osqp>=0.6.2->cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6)
#   Obtaining dependency information for qdldl from https://files.pythonhosted.org/packages/c0/43/6ac6a201bd38149aaa89f1429559c97ffd7e8cfeb651b5cfdceb06394e5c/qdldl-0.1.7.post4-cp310-cp310-macosx_11_0_arm64.whl.metadata
#   Using cached qdldl-0.1.7.post4-cp310-cp310-macosx_11_0_arm64.whl.metadata (1.7 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (4.9)
# Requirement already satisfied: mdit-py-plugins in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.4.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.0.3)
# Requirement already satisfied: uc-micro-py in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from linkify-it-py<3,>=1->markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.0.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/zhengshuang/Documents/ProgramingGuide/SourceCode/GithubRepo/everyfine/FinRLLearn/FinRL-Meta/.venv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (0.6.1)
# Using cached ccxt-3.1.60-py2.py3-none-any.whl (4.0 MB)
# Downloading exchange_calendars-4.5.8-py3-none-any.whl (196 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.8/196.8 kB 1.4 MB/s eta 0:00:00a 0:00:01m
# Using cached pyportfolioopt-1.5.5-py3-none-any.whl (61 kB)
# Using cached stockstats-0.5.4-py2.py3-none-any.whl (21 kB)
# Downloading cvxpy-1.6.0-cp310-cp310-macosx_10_9_universal2.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 3.4 MB/s eta 0:00:00a 0:00:01
# Using cached th-0.4.1-py3-none-any.whl (12 kB)
# Using cached clarabel-0.9.0-cp37-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (1.7 MB)
# Using cached niltype-1.0.2-py3-none-any.whl (5.3 kB)
# Using cached osqp-0.6.7.post3-cp310-cp310-macosx_11_0_arm64.whl (237 kB)
# Using cached scs-3.2.7-cp310-cp310-macosx_11_0_arm64.whl (93 kB)
# Using cached qdldl-0.1.7.post4-cp310-cp310-macosx_11_0_arm64.whl (98 kB)
# Building wheels for collected packages: finrl, elegantrl
#   Building wheel for finrl (pyproject.toml) ... done
#   Created wheel for finrl: filename=finrl-0.3.6-py3-none-any.whl size=4691755 sha256=3eda17b41326452cd26c735c3d8be4c6992e404366746fdf42d3e69aadd703a4
#   Stored in directory: /private/var/folders/dv/ly5hp_ms3bd9753868lg6c5w0000gn/T/pip-ephem-wheel-cache-4672zsug/wheels/72/3b/1a/0fc805a8cc65ecd5bfe4f74a3c586b6075678b8ba53fd8f749
#   Building wheel for elegantrl (setup.py) ... done
#   Created wheel for elegantrl: filename=ElegantRL-0.3.10-py3-none-any.whl size=281217 sha256=ee1159c2c477ce188370cf8e3a4a0bdf9a2bfc7029e9fdf684bf275e04d056b3
#   Stored in directory: /private/var/folders/dv/ly5hp_ms3bd9753868lg6c5w0000gn/T/pip-ephem-wheel-cache-4672zsug/wheels/c0/51/a5/b05f165548221bc570f7223babd33e2992fa873cdcebe2d229
# Successfully built finrl elegantrl
# Installing collected packages: niltype, th, scs, qdldl, clarabel, stockstats, osqp, exchange-calendars, elegantrl, cvxpy, ccxt, pyportfolioopt, finrl
#   Attempting uninstall: stockstats
#     Found existing installation: stockstats 0.6.2
#     Uninstalling stockstats-0.6.2:
#       Successfully uninstalled stockstats-0.6.2
#   Attempting uninstall: exchange-calendars
#     Found existing installation: exchange-calendars 3.6.3
#     Uninstalling exchange-calendars-3.6.3:
#       Successfully uninstalled exchange-calendars-3.6.3
#   Attempting uninstall: elegantrl
#     Found existing installation: elegantrl 0.3.6
#     Uninstalling elegantrl-0.3.6:
#       Successfully uninstalled elegantrl-0.3.6
#   Attempting uninstall: ccxt
#     Found existing installation: ccxt 4.4.31
#     Uninstalling ccxt-4.4.31:
#       Successfully uninstalled ccxt-4.4.31
# Successfully installed ccxt-3.1.60 clarabel-0.9.0 cvxpy-1.6.0 elegantrl-0.3.10 exchange-calendars-4.5.8 finrl-0.3.6 niltype-1.0.2 osqp-0.6.7.post3 pyportfolioopt-1.5.5 qdldl-0.1.7.post4 scs-3.2.7 stockstats-0.5.4 th-0.4.1
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# We also need to install quantstats, because the environment uses it to plot graphs
# !pip install quantstats

# %%
import logging
logging.getLogger('matplotlib.font_manager').disabled = True

# %% [markdown]
# #### Import the necessary code libraries

# %%
import copy
import gym
import torch
import random
import functools
import numpy as np
import torch.nn.functional as F

# %%
from tqdm.notebook import tqdm
from collections import deque
from torch import nn
from torch.utils.data import DataLoader
from torch.utils.data.dataset import IterableDataset
from torch.optim import AdamW
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# ## Fetch data
#
# In his paper, *Jiang et al* creates a portfolio composed by the top-11 cryptocurrencies based on 30-days volume. Since it's not specified when this classification was done, it's difficult to reproduce, so we will use a similar approach in the Brazillian stock market:
#
# - We select top-10 stocks from Brazillian stock market;
# - For simplicity, we disconsider stocks that have missing data for a days in period 2011-01-01 to 2019-12-31 (9 years);

# %%
# TOP_BRL = [
#     "VALE3.SA", "PETR4.SA", "ITUB4.SA", "BBDC4.SA",
#     "BBAS3.SA", "RENT3.SA", "LREN3.SA", "PRIO3.SA",
#     "WEGE3.SA", "ABEV3.SA"
# ]

TOP_BRL = [
    "VALE3.SA", "PETR4.SA", "ITUB4.SA", "BBDC4.SA",
    "BBAS3.SA", "RENT3.SA", "LREN3.SA", "PRIO3.SA",
    "WEGE3.SA", "ABEV3.SA"
]

# %%
print(len(TOP_BRL))

portfolio_raw_df = YahooDownloader(start_date="2011-01-01",
                                   end_date="2019-12-31",
                                   ticker_list= TOP_BRL).fetch_data()
portfolio_raw_df
# Out:
# 10
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  
# 18  2020-01-29  78.610481  81.084999  81.962502  81.112503  216229200  aapl
# 19  2020-01-30  78.496567  80.967499  81.022499  80.135002  126743200  aapl
#
#     day
# 0     3
# 1     4
# 2     0
# 3     1
# 4     2
# 5     3
# 6     4
# 7     0
# 8     1
# 9     2
# 10    3
# 11    4
# 12    1
# 13    2
# 14    3
# 15    4
# 16    0
# 17    1
# 18    2
# 19    3

# %%
portfolio_raw_df.groupby('tic').count()
# Out:
#           date  open  high   low  close  volume   day
# tic
# ABEV3.SA  2233  2233  2233  2233   2233    2233  2233
# BBAS3.SA  2233  2233  2233  2233   2233    2233  2233
# BBDC4.SA  2233  2233  2233  2233   2233    2233  2233
# ITUB4.SA  2233  2233  2233  2233   2233    2233  2233
# LREN3.SA  2233  2233  2233  2233   2233    2233  2233
# PETR4.SA  2233  2233  2233  2233   2233    2233  2233
# PRIO3.SA  2233  2233  2233  2233   2233    2233  2233
# RENT3.SA  2233  2233  2233  2233   2233    2233  2233
# VALE3.SA  2233  2233  2233  2233   2233    2233  2233
# WEGE3.SA  2233  2233  2233  2233   2233    2233  2233

# %% [markdown]
# ## Portfolio Optimization Environment

# %%
"""From FinRL https://github.com/AI4Finance-LLC/FinRL/tree/master/finrl/env"""
import gym
import math
import matplotlib
import numpy as np
import pandas as pd
from gym import spaces
from gym.utils import seeding

matplotlib.use('Agg')
import matplotlib.pyplot as plt
from stable_baselines3.common.vec_env import DummyVecEnv
from pathlib import Path

try:
    import quantstats as qs
except ModuleNotFoundError:
    raise ModuleNotFoundError(
        """QuantStats module not found, environment can't plot results and calculate indicadors.
        This module is not installed with FinRL. Install by running one of the options:
        pip install quantstats --upgrade --no-cache-dir
        conda install -c ranaroussi quantstats
        """
        )

# %%
class PortfolioOptimizationEnv(gym.Env):
    """A portfolio allocantion environment for OpenAI gym.

    This environment simulates the interactions between an agent and the financial market
    based on data provided by a dataframe. The dataframe contains the time series of
    features defined by the user (such as closing, high and low prices) and must have
    a time and a tic column with a list of datetimes and ticker symbols respectively.
    An example of dataframe is shown below::

            date        high            low             close           tic
        0   2020-12-23  0.157414        0.127420        0.136394        ADA-USD
        1   2020-12-23  34.381519       30.074295       31.097898       BNB-USD
        2   2020-12-23  24024.490234    22802.646484    23241.345703    BTC-USD
        3   2020-12-23  0.004735        0.003640        0.003768        DOGE-USD
        4   2020-12-23  637.122803      560.364258      583.714600      ETH-USD
        ... ...         ...             ...             ...             ...

    Based on this dataframe, the environment will create an observation space that can
    be a Dict or a Box. The Box observation space is a three-dimensional array of shape
    (f, n, t), where f is the number of features, n is the number of stocks in the
    portfolio and t is the user-defined time window. If the environment is created with
    the parameter return_last_action set to True, the observation space is a Dict with
    the following keys::

        {
        "state": three-dimensional Box (f, n, t) representing the time series,
        "last_action": one-dimensional Box (n+1,) representing the portfolio weights
        }

    Note that the action space of this environment is an one-dimensional Box with size
    n + 1 because the portfolio weights must contains the weights related to all the
    stocks in the portfolio and to the remaining cash.

    Attributes:
        action_space: Action space.
        observation_space: Observation space.
        episode_length: Number of timesteps of an episode.
    """
    metadata = {"render.modes": ["human"]}
    def __init__(
            self,
            df,
            initial_amount,
            order_df = True,
            return_last_action = False,
            normalize_df="by_previous_time",
            reward_scaling=1,
            comission_fee_model="trf",
            comission_fee_pct=0,
            features=['close', 'high', 'low'],
            valuation_feature='close',
            time_column='date',
            time_format='%Y-%m-%d',
            tic_column='tic',
            time_window=1,
            cwd="./",
            new_gym_api=False
    ):
        """Initializes environment's instance.

        Args:
            df: Dataframe with market information over a period of time.
            initial_amount: Initial amount of cash available to be invested.
            order_df: If True input dataframe is ordered by time.
            return_last_action: If True, observations also return the last performed
                action. Note that, in that case, the observation space is a Dict.
            normalize_df: Defines the normalization method applied to input dataframe.
                Possible values are "by_previous_time", "by_fist_time_window_value",
                "by_COLUMN_NAME" (where COLUMN_NAME must be changed to a real column
                name) and a custom function. If None no normalization is done.
            reward_scaling: A scaling factor to multiply the reward function. This
                factor can help training.
            comission_fee_model: Model used to simulate comission fee. Possible values
                are "trf" (for transaction remainder factor model) and "wvm" (for weights
                vector modifier model). If None, commission fees are not considered.
            comission_fee_pct: Percentage to be used in comission fee. It must be a value
                between 0 and 1.
            features: List of features to be considered in the observation space. The
                items of the list must be names of columns of the input dataframe.
            valuation_feature: Feature to be considered in the portfolio value calculation.
            time_column: Name of the dataframe's column that contain the datetimes that
                index the dataframe.
            time_format: Formatting string of time column.
            tic_name: Name of the dataframe's column that contain ticker symbols.
            time_window: Size of time window.
            cwd: Local repository in which resulting graphs will be saved.
            new_gym_api: If True, the environment will use the new gym api standard for
                step and reset methods.
        """
        self._time_window = time_window
        self._time_index = time_window - 1
        self._time_column = time_column
        self._time_format = time_format
        self._tic_column = tic_column
        self._df = df
        self._initial_amount = initial_amount
        self._return_last_action = return_last_action
        self._reward_scaling = reward_scaling
        self._comission_fee_pct = comission_fee_pct
        self._comission_fee_model = comission_fee_model
        self._features = features
        self._valuation_feature = valuation_feature
        self._cwd = Path(cwd)
        self._new_gym_api = new_gym_api
        
        # results file
        self._results_file = self._cwd / "results" / "rl"
        self._results_file.mkdir(parents=True,exist_ok=True)
        
        # price variation
        self._df_price_variation = None
        
        # preprocess data
        self._preprocess_data(order_df, normalize_df)
        
        #dims and spaces
        self._tic_list = self._df[self._tic_column].unique()
        self._stock_dim = len(self._tic_list)
        action_space = 1 + self._stock_dim
        
        # sort datetimes and define episode length
        self._sorted_times = sorted(set(self._df[time_column]))
        self.episode_length = len(self._sorted_times) - time_window + 1
        
        # define action space
        self.action_space = spaces.Box(low=0, high=1, shape=(action_space,))
        
        # define observation state
        if self._return_last_action:
            self.observation_space = spaces.Dict({
                "state": spaces.Box(
                    low=-np.inf, 
                    high=np.inf, 
                    shape=(
                        len(self._features),
                        self._stock_dim, 
                        self._time_window
                    )
                ),
                "last_action": spaces.Box(
                    low=0, high=1, shape=(action_space,)
                )
            })
        else:
            # if information about last action is not relevant,
            # a 3D observation space is defined
            self.observation_space = spaces.Box(
                low=-np.inf, 
                high=np.inf,
                shape=(
                    len(self._features),
                    self._stock_dim, 
                    self._time_window
                )
            )
        self._reset_memory()
        self._portfolio_value = self._initial_amount
        self._terminal = False
    
    def step(self, actions):
        """Performs a simulation step.

        Args:
            actions: An unidimensional array containing the new portfolio
                weights.

        Note:
            If the environment was created with "return_last_action" set to
            True, the next state returned will be a Dict. If it's set to False,
            the next state will be a Box. You can check the observation state
            through the attribute "observation_space".

        Returns:
            If "new_gym_api" is set to True, the following tuple is returned:
            (state, reward, terminal, truncated, info). If it's set to False,
            the following tuple is returned: (state, reward, terminal, info).

            state: Next simulation state.
            reward: Reward related to the last performed action.
            terminal: If True, the environment is in a terminal state.
            truncated: If True, the environment has passed it's simulation
                time limit. Currently, it's always False.
            info: A dictionary containing informations about the last state.
        """
        self._terminal = self._time_index >= len(self._sorted_times)-1
        if self._terminal:
            metrics_df = pd.DataFrame(
                {"date": self._date_memory,
                 "returns": self._portfolio_return_memory,
                 "rewards": self._portfolio_reward_memory,
                 "portfolio_values": self._asset_memory["final"]}
                )
            metrics_df.set_index("date", inplace=True)
            
            plt.plot(metrics_df["portfolio_values"], "r")
            plt.title("Portfolio Value Over Time")
            plt.xlabel("Time")
            plt.ylabel("Portfolio value")
            plt.savefig(self._results_file / "portfolio_value.png")
            plt.close()

            plt.plot(self._portfolio_reward_memory, "r")
            plt.title("Reward Over Time")
            plt.xlabel("Time")
            plt.ylabel("Reward")
            plt.savefig(self._results_file / "reward.png")
            plt.close()

            plt.plot(self._actions_memory)
            plt.title("Actions performed")
            plt.xlabel("Time")
            plt.ylabel("Weight")
            plt.savefig(self._results_file / "actions.png")
            plt.close()
            
            print("=================================")
            print("Initial portfolio value:{}".format(self._asset_memory['final'][0]))
            print("Final portfolio value: {}".format(self._portfolio_value))
            print("Final accumulative portfolio value: {}".format(self._portfolio_value / self._asset_memory['final'][0]))
            # print("Maximum DrawDown: {}".format(qs.stats.max_drawdown(metrics_df["portfolio_values"])))
            print("Sharpe ratio: {}".format(qs.stats.sharpe(metrics_df["returns"])))
            print("=================================")
            
            qs.plots.snapshot(metrics_df["returns"], show=False, savefig=self._results_file / "portfolio_summary.png")
            
            if self._new_gym_api:
                return self._state, self._reward, self._terminal, False, self._info
            return self._state, self._reward, self._terminal, self._info
        
        else:
            # transform action to numpy array (if it's a list)
            actions = np.array(actions, dtype=np.float32)
            
            # if necessary, normalize weights
            if math.isclose(np.sum(actions), 1, abs_tol=1e-6) and np.min(actions) >0:
                weights = actions
            else:
                weights = self._softmax_normalization(actions)
            
            # save initial portfolio weights for this time step
            self._actions_memory.append(weights)
            
            # get last step final weights and portfolio_value
            last_weights = self._final_weights[-1]
            
            # load next state
            self._time_index +=1
            self.state, self.info = self._get_state_and_info_from_time_index(self._time_index)
            
            # if using weights vector modifier, we need to modify weights vector
            if self._comission_fee_model == "wvm":
                delta_weights = weights - last_weights
                delta_assets = delta_weights[1:] # disconsider
                # calculate fees considering weights modification
                fees = np.sum(np.abs(delta_assets * self._portfolio_value))
                if fees > weights[0] * self._portfolio_value:
                    weights = last_weights
                    # maybe add negative reward
                else:
                    portfolio = weights * self._portfolio_value
                    portfolio[0] -= fees
                    self._portfolio_value = np.sum(portfolio) # new portfolio value
                    weights = portfolio / self._portfolio_value # new weights
            elif self._comission_fee_model == "trf":
                last_mu = 1
                mu = 1 - 2 * self._comission_fee_pct + self._comission_fee_pct ** 2
                while abs(mu - last_mu) > 1e-10:
                    last_mu = mu
                    mu = (1 - self._comission_fee_pct * weights[0] -
                          (2 * self._comission_fee_pct - self._comission_fee_pct ** 2) *
                          np.sum(np.maximum(last_weights[1:] - mu * weights[1:], 0))) / (1 - self._comission_fee_pct * weights[0])
                self._info["trf_mu"] = mu
                self._portfolio_value = mu * self._portfolio_value
                
            # save initial portfolio value of this time step
            self._asset_memory['initial'].append(self._portfolio_value)
            
            # time passes and time variation changes the portfolio distribution
            portfolio = self._portfolio_value * (weights * self._price_variation)
            
            # calculate new portfolio value and weights
            self._portfolio_value = np.sum(portfolio)
            weights = portfolio / self._portfolio_value
            
            # save final portfolio value and weights of this time step
            self._asset_memory["final"].append(self._portfolio_value)
            self._final_weights.append(weights)
            
            # save date memory
            self._date_memory.append(self._info["end_time"])
            
            # define portfolio return
            rate_of_return = self._asset_memory["final"][-1] / self._asset_memory["final"][-2]
            portfolio_return = rate_of_return - 1
            portfolio_reward = np.log(rate_of_return)
            
            # save portfolio return memory
            self._portfolio_return_memory.append(portfolio_return)
            self._portfolio_reward_memory.append(portfolio_reward)
            
            # Define portfolio return
            self._reward = portfolio_reward
            self._reward = self._reward * self._reward_scaling
        if self._new_gym_api:
            return self._state, self._reward, self._terminal, False, self._info
        return self._state, self._reward, self._terminal, self._info
    
    def reset(self):
        """Resets the environment and returns it to its initial state (the
        fist date of the dataframe).

        Note:
            If the environment was created with "return_last_action" set to
            True, the initial state will be a Dict. If it's set to False,
            the initial state will be a Box. You can check the observation
            state through the attribute "observation_space".

        Returns:
            If "new_gym_api" is set to True, the following tuple is returned:
            (state, info). If it's set to False, only the initial state is
            returned.

            state: Initial state.
            info: Initial state info.
        """
        # time_index must start a little bit in the future to implement lookback
        self._time_index = self._time_window - 1
        self._reset_memory()
        self._state, self._info = self._get_state_and_info_from_time_index(self._time_index)
        self._portfolio_value = self._initial_amount
        self._terminal = False

        if self._new_gym_api:
            return self._state, self._info
        return self._state
    
    def _get_state_and_info_from_time_index(self, time_index):
        """Gets state and information given a time index. It also updates "data"
        attribute with information about the current simulation step.

        Args:
            time_index: An integer that represents the index of a specific datetime.
                The initial datetime of the dataframe is given by 0.

        Note:
            If the environment was created with "return_last_action" set to
            True, the returned state will be a Dict. If it's set to False,
            the returned state will be a Box. You can check the observation
            state through the attribute "observation_space".

        Returns:
            A tuple with the following form: (state, info).

            state: The state of the current time index. It can be a Box or a Dict.
            info: A dictionary with some informations about the current simulation
                step. The dict has the following keys::

                {
                "tics": List of ticker symbols,
                "start_time": Start time of current time window,
                "start_time_index": Index of start time of current time window,
                "end_time": End time of current time window,
                "end_time_index": Index of end time of current time window,
                "data": Data related to the current time window,
                "price_variation": Price variation of current time step
                }
        """
        # returns state in form (channels, tics, timesteps)
        end_time = self._sorted_times[time_index]
        start_time = self._sorted_times[time_index - (self._time_window - 1)]
        
        # define data to be used in this time step
        self._data = self._df[
             (self._df[self._time_column] >= start_time) &
            (self._df[self._time_column] <= end_time)
        ][[self._time_column, self._tic_column] + self._features]
        
        # define price variation of this time_step
        self._price_variation = self._df_price_variation[
                self._df_price_variation[self._time_column] == end_time
            ][self._valuation_feature].to_numpy()
        self._price_variation = np.insert(self._price_variation, 0, 1)
        
        # define state to be returned
        state = None
        for tic in self._tic_list:
            tic_data = self._data[self._data[self._tic_column] == tic]
            tic_data = tic_data[self._features].to_numpy().T
            tic_data = tic_data[..., np.newaxis]
            state = tic_data if state is None else np.append(state, tic_data, axis=2)
        state = state.transpose((0, 2, 1))
        info = {
            "tics": self._tic_list,
            "start_time": start_time,
            "start_time_index": time_index - (self._time_window - 1),
            "end_time": end_time,
            "end_time_index": time_index,
            "data": self._data,
            "price_variation": self._price_variation
        }
        return self._standardize_state(state), info
    
    def render(self, mode="human"):
        """Renders the environment.

        Returns:
            Observation of current simulation step.
        """
        return self._state
    
    def _softmax_normalization(self, actions):
        """Normalizes the action vector using softmax function.

        Returns:
            Normalized action vector (portfolio vector).
        """
        numerator = np.exp(actions)
        denominator = np.sum(np.exp(actions))
        softmax_output = numerator / denominator
        return softmax_output
    def enumerate_portfolio(self):
        """Enumerates the current porfolio by showing the ticker symbols
        of all the investments considered in the portfolio.
        """
        print("Index: 0. Tic: Cash")
        for index, tic in enumerate(self._tic_list):
            print("Index: {}. Tic: {}".format(index + 1, tic))
            
    def _preprocess_data(self, order, normalize):
        """Orders and normalizes the environment's dataframe.

        Args:
            order: If true, the dataframe will be ordered by ticker list
                and datetime.
            normalize: Defines the normalization method applied to the dataframe.
                Possible values are "by_previous_time", "by_fist_time_window_value",
                "by_COLUMN_NAME" (where COLUMN_NAME must be changed to a real column
                name) and a custom function. If None no normalization is done.
        """
        # order time dataframe by tic and time
        if order:
            self._df = self._df.sort_values(by=[self._tic_column, self._time_column])
        # defining price variation after ordering dataframe
        self._df_price_variation = self._temporal_variation_df()
        # apply normalization
        if normalize:
            self._normalize_dataframe(normalize)
        # transform str to datetime
        self._df[self._time_column] = pd.to_datetime(self._df[self._time_column])
        self._df_price_variation[self._time_column] = pd.to_datetime(self._df_price_variation[self._time_column])
        # transform numeric variables to float32 (compatibility with pytorch)
        self._df[self._features] = self._df[self._features].astype("float32")
        self._df_price_variation[self._features] = self._df_price_variation[self._features].astype("float32")
        
    def _reset_memory(self):
        """Resets the environment's memory."""
        date_time = self._sorted_times[self._time_index]
        # memorize portfolio value each step
        self._asset_memory = {
            "initial" : [self._initial_amount],
            "final" : [self._initial_amount]
        }
        # memorize portfolio return and reward each step
        self._portfolio_return_memory = [0]
        self._portfolio_reward_memory = [0]
        # initial action: all money is allocated in cash
        self._actions_memory = [np.array([1] + [0] * self._stock_dim, dtype=np.float32)]
        # memorize portfolio weights at the ending of time step
        self._final_weights = [np.array([1] + [0] * self._stock_dim, dtype=np.float32)]
        # memorize datetimes
        self._date_memory = [date_time]
        
    def _standardize_state(self, state):
        """Standardize the state given the observation space. If "return_last_action"
        is set to False, a three-dimensional box is returned. If it's set to True, a
        dictionary is returned. The dictionary follows the standard below::

            {
            "state": Three-dimensional box representing the current state,
            "last_action": One-dimensional box representing the last action
            }
        """
        last_action = self._actions_memory[-1]
        if self._return_last_action:
            return { "state": state, "last_action": last_action }
        else:
            return state
        
    def _normalize_dataframe(self, normalize):
        """"Normalizes the environment's dataframe.

        Args:
            normalize: Defines the normalization method applied to the dataframe.
                Possible values are "by_previous_time", "by_fist_time_window_value",
                "by_COLUMN_NAME" (where COLUMN_NAME must be changed to a real column
                name) and a custom function. If None no normalization is done.

        Note:
            If a custom function is used in the normalization, it must have an
            argument representing the environment's dataframe.
        """
        if type(normalize) == str:
            if normalize == "by_fist_time_window_value":
                print("Normalizing {} by first time window value...".format(self._features))
                self._df = self._temporal_variation_df(self._time_window - 1)
            elif normalize == "by_previous_time":
                print("Normalizing {} by previous time...".format(self._features))
                self._df = self._temporal_variation_df()
            elif normalize.startswith("by_"):
                normalizer_column = normalize[3:]
                print("Normalizing {} by {}".format(self._features, normalizer_column))
                for column in self._features:
                    self._df[column] = self._df[column] / self._df[normalizer_column]
        elif callable(normalize):
            print("Applying custom normalization function...")
            self._df = normalize(self._df)
        else:
            print("No normalization was performed.")
            
    def _temporal_variation_df(self, periods=1):
        """Calculates the temporal variation dataframe. For each feature, this
        dataframe contains the rate of the current feature's value and the last
        feature's value given a period. It's used to normalize the dataframe.

        Args:
            periods: Periods (in time indexes) to calculate temporal variation.

        Returns:
            Temporal variation dataframe.
        """
        df_temporal_variation = self._df.copy()
        prev_columns = []
        for column in self._features:
            prev_column = "prev_{}".format(column)
            prev_columns.append(prev_column)
            df_temporal_variation[prev_column] = df_temporal_variation.groupby(self._tic_column)[column].shift(periods=periods)
            df_temporal_variation[column] = df_temporal_variation[column] / df_temporal_variation[prev_column]
        df_temporal_variation = df_temporal_variation.drop(columns=prev_columns).fillna(1).reset_index(drop=True)
        return df_temporal_variation
    
    def _seed(self, seed=None):
        """Seeds the sources of randomness of this environment to guarantee
        reproducibility.

        Args:
            seed: Seed value to be applied.

        Returns:
            Seed value applied.
        """
        self.np_random, seed = seeding.np_random(seed)
        return [seed]
    
    def get_sb_env(self, env_number=1):
        """Generates an environment compatible with Stable Baselines 3. The
        generated environment is a vectorized version of the current one.

        Returns:
            A tuple with the generated environment and an initial observation.
        """
        e = DummyVecEnv([lambda: self] * env_number)
        obs = e.reset()
        return e, obs

# %% [markdown]
# ## Define Architecture

# %%
# Define constants
PORTFOLIO_SIZE = len(TOP_BRL)

# %% [markdown]
# #### Create the gradient policy
#
# The gradient policy below is identical to the EIIE architecture from *Jiang et al* paper.

# %%
class GradientPolicy(nn.Module):
    def __init__(self):
        """DDPG policy network initializer."""
        super().__init__()

        self.sequential = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=2, kernel_size=(1, 3)),
            nn.ReLU(),
            nn.Conv2d(in_channels=2, out_channels=20, kernel_size=(1, 48)),
            nn.ReLU()
        )

        self.final_convolution = nn.Conv2d(in_channels=21, out_channels=1, kernel_size=(1, 1))

        self.softmax = nn.Sequential(
            nn.Softmax(dim=-1)
        )

    def mu(self, observation, last_action):
        """Defines a most favorable action of this policy given input x.

        Args:
          observation: environment observation .
          last_action: Last action performed by agent.

        Returns:
          Most favorable action.
        """

        if isinstance(observation, np.ndarray):
            observation = torch.from_numpy(observation).to(device)
        if isinstance(last_action, np.ndarray):
            last_action = torch.from_numpy(last_action).to(device)

        last_stocks, cash_bias = self._process_last_action(last_action)

        output = self.sequential(observation) # shape [N, PORTFOLIO_SIZE + 1, 19, 1]
        output = torch.cat([output, last_stocks], dim=1) # shape [N, 21, PORTFOLIO_SIZE, 1]
        output = self.final_convolution(output) # shape [N, 1, PORTFOLIO_SIZE, 1]
        output = torch.cat([output, cash_bias], dim=2) # shape [N, 1, PORTFOLIO_SIZE + 1, 1]

        # output shape must be [N, features] = [1, PORTFOLIO_SIZE + 1], being N batch size (1)
        # and size the number of features (weights vector).
        output = torch.squeeze(output, 3)
        output = torch.squeeze(output, 1) # shape [N, PORTFOLIO_SIZE + 1]

        output = self.softmax(output)

        return output

    def forward(self, observation, last_action):
        """Policy network's forward propagation.

        Args:
          observation: environment observation (dictionary).
          epsilon: exploration noise to be applied.

        Returns:
          Action to be taken (numpy array).
        """
        mu = self.mu(observation, last_action)
        action = mu.cpu().detach().numpy().squeeze()
        return action

    def _process_last_action(self, last_action):
        batch_size = last_action.shape[0]
        stocks = last_action.shape[1] - 1
        last_stocks = last_action[:, 1:].reshape((batch_size, 1, stocks, 1))
        cash_bias = last_action[:, 0].reshape((batch_size, 1, 1, 1))
        return last_stocks, cash_bias

# %% [markdown]
# #### Portfolio Vector Memory
#
# The portfolio vector memory is an object that saves all the portfolio vectors generated by the policy. It's useful because the algorithm can get the last action performed, an information necessary to do forward propagation. Read *Jiang et al* article for more information.

# %%
class PVM:
    def __init__(self, capacity):
        """Initializes portfolio vector memory.

        Args:
          capacity: Max capacity of memory.
        """
        # initially, memory will have the same actions
        self.capacity = capacity
        self.reset()

    def reset(self):
        self.memory = [np.array([1] + [0] * PORTFOLIO_SIZE, dtype=np.float32)] * (self.capacity + 1)
        self.index = 0 # initial index to retrieve data

    def retrieve(self):
        last_action = self.memory[self.index]
        self.index = 0 if self.index == self.capacity else self.index + 1
        return last_action

    def add(self, action):
        self.memory[self.index] = action

# %% [markdown]
# #### ReplayBuffer and RLDataset
#
# The replay buffer implemented in this work is slightly different from the one in famous algorithms. Usually, experiences are constantly added to the replay buffer and when it's completely filled, older experiences are overwritten by new ones (deque behavior). A reinforcement learning algorithm can constantly sample experiences from the buffer to update their neural networks and, as the time passes, older experiences will be disconsidered due to the deque behavior.
#
# In this replay buffer, however, the deque behavior is still present, but when an algorithm sample a batch of experiences, all the experiences in the replay buffer are returned and it is cleared. This behavior is necessary given the policy gradient algorithm introduced by *Jiang et al*.

# %%
class ReplayBuffer:
  def __init__(self, capacity):
    """Initializes replay buffer.

    Args:
      capacity: Max capacity of buffer.
    """
    self.buffer = deque(maxlen=capacity)

  def __len__(self):
    """Represents the size of the buffer

    Returns:
      Size of the buffer.
    """
    return len(self.buffer)

  def append(self, experience):
    """Append experience to buffer. When buffer is full, it pops
       an old experience.

    Args:
      experience: experience to be saved.
    """
    self.buffer.append(experience)

  def sample(self):
    """Sample from replay buffer. All data from replay buffer is
    returned and the buffer is cleared.

    Returns:
      Sample of batch_size size.
    """
    buffer = list(self.buffer)
    self.buffer.clear()
    return buffer

# %%
class RLDataset(IterableDataset):
  def __init__(self, buffer):
    """Initializes reinforcement learning dataset.

    Args:
        buffer: replay buffer to become iterable dataset.

    Note:
        It's a subclass of pytorch's IterableDataset,
        check https://pytorch.org/docs/stable/data.html#torch.utils.data.IterableDataset
    """
    self.buffer = buffer

  def __iter__(self):
    """Iterates over RLDataset.

    Returns:
      Every experience of a sample from replay buffer.
    """
    for experience in self.buffer.sample():
        yield experience

# %% [markdown]
# ### Create Polyak average function
#
# The Polyak average function allows us to have a target function that is incrementally updated. It's useful to avoid oscillations in the final policy performance.

# %%
def polyak_average(net, target_net, tau=0.01):
  """Applies polyak average to incrementally update target net.

  Args:
    net: trained neural network.
    target_net: target neural network.
    tau: update rate.
  """
  for qp, tp in zip(net.parameters(), target_net.parameters()):
    tp.data.copy_(tau * qp.data + (1 - tau) * tp.data)

# %% [markdown]
# ### Create PG class
#
# This class implements the Policy Gradient algorithm used in Jiang et al paper. This algorithm is inspired by DDPG (deep deterministic policy gradient), but there are a couple of differences:
# DDPG is an actor-critic algorithm, so it has an actor and a critic neural network. The algorithm below, however, doesn't have a critic neural network and uses the portfolio value as value function: the policy will be updated to maximize the portfolio value.
# DDPG usually makes use of a noise parameter in the action during training to create an exploratory behavior. PG algorithm, on the other hand, has a full-exploit approach.
# DDPG randomly samples experiences from its replay buffer. The implemented policy gradient, however, samples a sequential batch of experiences in time, to make it possible to calculate the variation of the portfolio value in the batch and use it as value function.
# The algorithm can be described as follows:
# Initializes policy network, target policy network (if used) and replay buffer;
# For each episode, do the following:
# For each period of batch_size timesteps, do the following:
# For each timestep, define an action to be performed, simulate the timestep and save the experiences in the replay buffer.
# After batch_size timesteps are simulated, sample the replay buffer.
# Update target policy network (if used).
# Calculate the value function:  , where   is the action performed at timestep t,   is the price variation vector at timestep t and   is the transaction remainder factor at timestep t. Check Jiang et al paper for more details.
# Perform gradient ascent in the policy network.
# If, in the and of episode, there is sequence of remaining experiences in the replay buffer, perform steps "a" to "e" with the remaining experiences.

# %%
class PG:
    def __init__(self,
                 env,
                 batch_size=100,
                 lr=1e-3,
                 optimizer=AdamW,
                 tau=0.05):
        """Initializes Policy Gradient for portfolio optimization.

          Args:
            env: environment.
            batch_size: batch size to train neural network.
            lr: policy neural network learning rate.
            optim: Optimizer of neural network.
            tau: update rate in Polyak averaging.
        """
        # environment
        self.env = env

        # neural networks
        self.policy = GradientPolicy().to(device)
        self.target_policy = copy.deepcopy(self.policy)
        self.optimizer = optimizer(self.policy.parameters(), lr=lr)
        self.tau = tau

        # replay buffer and portfolio vector memory
        self.batch_size = batch_size
        self.buffer = ReplayBuffer(capacity=batch_size)
        self.pvm = PVM(self.env.episode_length)

        # dataset and dataloader
        dataset = RLDataset(self.buffer)
        self.dataloader = DataLoader(
            dataset=dataset,
            batch_size=batch_size,
            shuffle=False,
            pin_memory=True)

    def train(self, episodes=100):
        """Training sequence

        Args:
            episodes: Number of episodes to simulate
        """
        for i in tqdm(range(1, episodes + 1)):
            print('Episode {}/{}'.format(i, episodes))
            obs = self.env.reset() # observation
            self.pvm.reset() # reset portfolio vector memory
            done = False

            while not done:
                # define last_action and action and update portfolio vector memory
                last_action = self.pvm.retrieve()
                obs_batch = np.expand_dims(obs, axis=0)
                last_action_batch = np.expand_dims(last_action, axis=0)
                action = self.policy(obs_batch, last_action_batch)
                self.pvm.add(action)

                # run simulation step
                next_obs, reward, done, info = self.env.step(action)

                # add experience to replay buffer
                exp = (obs, last_action, info["price_variation"], info["trf_mu"])
                self.buffer.append(exp)

                # update policy networks
                if len(self.buffer) == self.batch_size:
                    self._gradient_ascent()

                obs = next_obs

            # gradient ascent with episode remaining buffer data
            self._gradient_ascent()



    def _gradient_ascent(self):
        # update target neural network
        polyak_average(self.policy, self.target_policy, tau=self.tau)

        # get batch data from dataloader
        obs, last_actions, price_variations, trf_mu = next(iter(self.dataloader))
        obs = obs.to(device)
        last_actions = last_actions.to(device)
        price_variations = price_variations.to(device)
        trf_mu = trf_mu.unsqueeze(1).to(device)

        # define policy loss (negative for gradient ascent)
        mu = self.policy.mu(obs, last_actions)
        policy_loss = - torch.mean(torch.log(torch.sum(mu * price_variations * trf_mu, dim=1)))

        # update policy network
        self.policy.zero_grad()
        policy_loss.backward()
        self.optimizer.step()

# %% [markdown]
# ### Train Algorithm

# %%
type(portfolio_raw_df.date[0])
# Out:
# str

# %%
df_portfolio = portfolio_raw_df[["date", "tic", "close", "high", "low"]]

# %%
EPISODES = 1000

# %%
environment = PortfolioOptimizationEnv(
        df_portfolio,
        initial_amount=100000,
        comission_fee_pct=0.0025,
        time_window=50,
        features=["close", "high", "low"]
    )

algo = PG(environment, lr=0.0001)

algo.train(episodes=EPISODES)
# Out:
# Normalizing ['close', 'high', 'low'] by previous time...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Episode 1/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 285183.65625
# Final accumulative portfolio value: 2.8518365625
# Sharpe ratio: 0.632368836599431
# =================================
# Episode 2/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 283492.25
# Final accumulative portfolio value: 2.8349225
# Sharpe ratio: 0.6283317153263785
# =================================
# Episode 3/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 282040.8125
# Final accumulative portfolio value: 2.820408125
# Sharpe ratio: 0.6248620303642852
# =================================
# Episode 4/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 280820.03125
# Final accumulative portfolio value: 2.8082003125
# Sharpe ratio: 0.6219176636140636
# =================================
# Episode 5/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 279469.21875
# Final accumulative portfolio value: 2.7946921875
# Sharpe ratio: 0.6186402517939896
# =================================
# Episode 6/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 277955.6875
# Final accumulative portfolio value: 2.779556875
# Sharpe ratio: 0.6149809037507713
# =================================
# Episode 7/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 276351.3125
# Final accumulative portfolio value: 2.763513125
# Sharpe ratio: 0.6110763141764093
# =================================
# Episode 8/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 274660.15625
# Final accumulative portfolio value: 2.7466015625
# Sharpe ratio: 0.60696060850082
# =================================
# Episode 9/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 272925.84375
# Final accumulative portfolio value: 2.7292584375
# Sharpe ratio: 0.6027364005513804
# =================================
# Episode 10/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 271186.3125
# Final accumulative portfolio value: 2.711863125
# Sharpe ratio: 0.5984970585629977
# =================================
# Episode 11/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 269500.34375
# Final accumulative portfolio value: 2.6950034375
# Sharpe ratio: 0.5943806926655898
# =================================
# Episode 12/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 267921.0
# Final accumulative portfolio value: 2.67921
# Sharpe ratio: 0.590503829454426
# =================================
# Episode 13/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 266423.78125
# Final accumulative portfolio value: 2.6642378125
# Sharpe ratio: 0.5868460456788663
# =================================
# Episode 14/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 265082.0625
# Final accumulative portfolio value: 2.650820625
# Sharpe ratio: 0.5835482146431556
# =================================
# Episode 15/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 263870.28125
# Final accumulative portfolio value: 2.6387028125
# Sharpe ratio: 0.5805683834386852
# =================================
# Episode 16/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 262810.5
# Final accumulative portfolio value: 2.628105
# Sharpe ratio: 0.5779537070146903
# =================================
# Episode 17/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 261879.78125
# Final accumulative portfolio value: 2.6187978125
# Sharpe ratio: 0.575657744417722
# =================================
# Episode 18/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 261047.40625
# Final accumulative portfolio value: 2.6104740625
# Sharpe ratio: 0.5736171611984577
# =================================
# Episode 19/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 260343.75
# Final accumulative portfolio value: 2.6034375
# Sharpe ratio: 0.5718696292697035
# =================================
# Episode 20/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 259757.265625
# Final accumulative portfolio value: 2.59757265625
# Sharpe ratio: 0.5704055883591609
# =================================
# Episode 21/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 259230.6875
# Final accumulative portfolio value: 2.592306875
# Sharpe ratio: 0.5690977325980259
# =================================
# Episode 22/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 258771.734375
# Final accumulative portfolio value: 2.58771734375
# Sharpe ratio: 0.5679641717333186
# =================================
# Episode 23/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 258393.390625
# Final accumulative portfolio value: 2.58393390625
# Sharpe ratio: 0.567012428200883
# =================================
# Episode 24/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 258076.09375
# Final accumulative portfolio value: 2.5807609375
# Sharpe ratio: 0.5662126851612744
# =================================
# Episode 25/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 257798.640625
# Final accumulative portfolio value: 2.57798640625
# Sharpe ratio: 0.5655055187482466
# =================================
# Episode 26/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 257552.421875
# Final accumulative portfolio value: 2.57552421875
# Sharpe ratio: 0.5648847965244402
# =================================
# Episode 27/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 257328.78125
# Final accumulative portfolio value: 2.5732878125
# Sharpe ratio: 0.5643246446449683
# =================================
# Episode 28/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 257159.5625
# Final accumulative portfolio value: 2.571595625
# Sharpe ratio: 0.5638818487866613
# =================================
# Episode 29/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 257004.546875
# Final accumulative portfolio value: 2.57004546875
# Sharpe ratio: 0.5634760126873765
# =================================
# Episode 30/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 256831.390625
# Final accumulative portfolio value: 2.56831390625
# Sharpe ratio: 0.5630556870037511
# =================================
# Episode 31/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 256722.625
# Final accumulative portfolio value: 2.56722625
# Sharpe ratio: 0.5627569170675973
# =================================
# Episode 32/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 256622.9375
# Final accumulative portfolio value: 2.566229375
# Sharpe ratio: 0.5624924797425381
# =================================
# Episode 33/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 256529.125
# Final accumulative portfolio value: 2.56529125
# Sharpe ratio: 0.5622399364284827
# =================================
# Episode 34/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 256429.9375
# Final accumulative portfolio value: 2.564299375
# Sharpe ratio: 0.5619905133325331
# =================================
# Episode 35/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 256343.53125
# Final accumulative portfolio value: 2.5634353125
# Sharpe ratio: 0.5617689739315219
# =================================
# Episode 36/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 256285.421875
# Final accumulative portfolio value: 2.56285421875
# Sharpe ratio: 0.5616022752019532
# =================================
# Episode 37/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 256251.4375
# Final accumulative portfolio value: 2.562514375
# Sharpe ratio: 0.5614832746403488
# =================================
# Episode 38/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 256177.734375
# Final accumulative portfolio value: 2.56177734375
# Sharpe ratio: 0.5612968969240791
# =================================
# Episode 39/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 256128.359375
# Final accumulative portfolio value: 2.56128359375
# Sharpe ratio: 0.5611643916048816
# =================================
# Episode 40/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 256083.546875
# Final accumulative portfolio value: 2.56083546875
# Sharpe ratio: 0.5610377862068422
# =================================
# Episode 41/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 256036.421875
# Final accumulative portfolio value: 2.56036421875
# Sharpe ratio: 0.5609093654909877
# =================================
# Episode 42/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 256004.015625
# Final accumulative portfolio value: 2.56004015625
# Sharpe ratio: 0.5608135660767438
# =================================
# Episode 43/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255968.71875
# Final accumulative portfolio value: 2.5596871875
# Sharpe ratio: 0.5607100228759064
# =================================
# Episode 44/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255948.296875
# Final accumulative portfolio value: 2.55948296875
# Sharpe ratio: 0.5606421438625449
# =================================
# Episode 45/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255917.0625
# Final accumulative portfolio value: 2.559170625
# Sharpe ratio: 0.5605501275577236
# =================================
# Episode 46/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255900.09375
# Final accumulative portfolio value: 2.5590009375
# Sharpe ratio: 0.5604859141630611
# =================================
# Episode 47/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255878.15625
# Final accumulative portfolio value: 2.5587815625
# Sharpe ratio: 0.5604188533380585
# =================================
# Episode 48/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255864.859375
# Final accumulative portfolio value: 2.55864859375
# Sharpe ratio: 0.5603652727018692
# =================================
# Episode 49/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255845.796875
# Final accumulative portfolio value: 2.55845796875
# Sharpe ratio: 0.5603006189539381
# =================================
# Episode 50/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255815.640625
# Final accumulative portfolio value: 2.55815640625
# Sharpe ratio: 0.5602187028661945
# =================================
# Episode 51/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255858.96875
# Final accumulative portfolio value: 2.5585896875
# Sharpe ratio: 0.5602697240270457
# =================================
# Episode 52/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255813.296875
# Final accumulative portfolio value: 2.55813296875
# Sharpe ratio: 0.5601664172355495
# =================================
# Episode 53/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255814.484375
# Final accumulative portfolio value: 2.55814484375
# Sharpe ratio: 0.560128359641485
# =================================
# Episode 54/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255789.75
# Final accumulative portfolio value: 2.5578975
# Sharpe ratio: 0.5600693007696643
# =================================
# Episode 55/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255787.125
# Final accumulative portfolio value: 2.55787125
# Sharpe ratio: 0.5600316322597569
# =================================
# Episode 56/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255748.5625
# Final accumulative portfolio value: 2.557485625
# Sharpe ratio: 0.5599478522681381
# =================================
# Episode 57/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255755.21875
# Final accumulative portfolio value: 2.5575521875
# Sharpe ratio: 0.5599310209085054
# =================================
# Episode 58/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255748.1875
# Final accumulative portfolio value: 2.557481875
# Sharpe ratio: 0.5598996304952212
# =================================
# Episode 59/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255741.109375
# Final accumulative portfolio value: 2.55741109375
# Sharpe ratio: 0.559859488900521
# =================================
# Episode 60/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255741.84375
# Final accumulative portfolio value: 2.5574184375
# Sharpe ratio: 0.5598361329646842
# =================================
# Episode 61/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255749.25
# Final accumulative portfolio value: 2.5574925
# Sharpe ratio: 0.5598284779735011
# =================================
# Episode 62/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255709.265625
# Final accumulative portfolio value: 2.55709265625
# Sharpe ratio: 0.5597380984541352
# =================================
# Episode 63/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255726.3125
# Final accumulative portfolio value: 2.557263125
# Sharpe ratio: 0.5597366075352636
# =================================
# Episode 64/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255755.4375
# Final accumulative portfolio value: 2.557554375
# Sharpe ratio: 0.5597689831476952
# =================================
# Episode 65/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255716.515625
# Final accumulative portfolio value: 2.55716515625
# Sharpe ratio: 0.5596748175555664
# =================================
# Episode 66/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255722.203125
# Final accumulative portfolio value: 2.55722203125
# Sharpe ratio: 0.5596679091897409
# =================================
# Episode 67/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255724.9375
# Final accumulative portfolio value: 2.557249375
# Sharpe ratio: 0.5596474520829453
# =================================
# Episode 68/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255733.453125
# Final accumulative portfolio value: 2.55733453125
# Sharpe ratio: 0.5596382971356094
# =================================
# Episode 69/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255704.65625
# Final accumulative portfolio value: 2.5570465625
# Sharpe ratio: 0.5595592160681501
# =================================
# Episode 70/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255780.59375
# Final accumulative portfolio value: 2.5578059375
# Sharpe ratio: 0.5596769826744251
# =================================
# Episode 71/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255787.609375
# Final accumulative portfolio value: 2.55787609375
# Sharpe ratio: 0.5596616118692463
# =================================
# Episode 72/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255772.96875
# Final accumulative portfolio value: 2.5577296875
# Sharpe ratio: 0.5596121785524851
# =================================
# Episode 73/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255769.5625
# Final accumulative portfolio value: 2.557695625
# Sharpe ratio: 0.5595827048755452
# =================================
# Episode 74/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255763.375
# Final accumulative portfolio value: 2.55763375
# Sharpe ratio: 0.5595464540709267
# =================================
# Episode 75/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255779.15625
# Final accumulative portfolio value: 2.5577915625
# Sharpe ratio: 0.5595520398206252
# =================================
# Episode 76/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255779.390625
# Final accumulative portfolio value: 2.55779390625
# Sharpe ratio: 0.5595274252494586
# =================================
# Episode 77/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255771.828125
# Final accumulative portfolio value: 2.55771828125
# Sharpe ratio: 0.5594905178798054
# =================================
# Episode 78/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255779.421875
# Final accumulative portfolio value: 2.55779421875
# Sharpe ratio: 0.5594841017487189
# =================================
# Episode 79/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255784.140625
# Final accumulative portfolio value: 2.55784140625
# Sharpe ratio: 0.5594692129664405
# =================================
# Episode 80/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255771.375
# Final accumulative portfolio value: 2.55771375
# Sharpe ratio: 0.5594204728185254
# =================================
# Episode 81/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255778.984375
# Final accumulative portfolio value: 2.55778984375
# Sharpe ratio: 0.5594085120478679
# =================================
# Episode 82/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255775.109375
# Final accumulative portfolio value: 2.55775109375
# Sharpe ratio: 0.5593744958331133
# =================================
# Episode 83/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255772.984375
# Final accumulative portfolio value: 2.55772984375
# Sharpe ratio: 0.5593448180421151
# =================================
# Episode 84/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255779.5
# Final accumulative portfolio value: 2.557795
# Sharpe ratio: 0.5593298860113971
# =================================
# Episode 85/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255772.625
# Final accumulative portfolio value: 2.55772625
# Sharpe ratio: 0.5592906146531851
# =================================
# Episode 86/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255777.296875
# Final accumulative portfolio value: 2.55777296875
# Sharpe ratio: 0.5592765710693507
# =================================
# Episode 87/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255771.390625
# Final accumulative portfolio value: 2.55771390625
# Sharpe ratio: 0.5592385418674867
# =================================
# Episode 88/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255777.78125
# Final accumulative portfolio value: 2.5577778125
# Sharpe ratio: 0.5592217985605298
# =================================
# Episode 89/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255780.234375
# Final accumulative portfolio value: 2.55780234375
# Sharpe ratio: 0.5591960545735021
# =================================
# Episode 90/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255774.0
# Final accumulative portfolio value: 2.55774
# Sharpe ratio: 0.5591567898576199
# =================================
# Episode 91/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255775.375
# Final accumulative portfolio value: 2.55775375
# Sharpe ratio: 0.5591290979247124
# =================================
# Episode 92/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255766.0625
# Final accumulative portfolio value: 2.557660625
# Sharpe ratio: 0.5590800243686127
# =================================
# Episode 93/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255768.359375
# Final accumulative portfolio value: 2.55768359375
# Sharpe ratio: 0.5590531791598328
# =================================
# Episode 94/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255762.625
# Final accumulative portfolio value: 2.55762625
# Sharpe ratio: 0.5590096366971424
# =================================
# Episode 95/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255763.875
# Final accumulative portfolio value: 2.55763875
# Sharpe ratio: 0.5589812921655342
# =================================
# Episode 96/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255762.640625
# Final accumulative portfolio value: 2.55762640625
# Sharpe ratio: 0.5589496063425525
# =================================
# Episode 97/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255763.796875
# Final accumulative portfolio value: 2.55763796875
# Sharpe ratio: 0.5589185020905281
# =================================
# Episode 98/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255758.09375
# Final accumulative portfolio value: 2.5575809375
# Sharpe ratio: 0.5588730571173851
# =================================
# Episode 99/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255766.234375
# Final accumulative portfolio value: 2.55766234375
# Sharpe ratio: 0.5588525781156201
# =================================
# Episode 100/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255766.0
# Final accumulative portfolio value: 2.55766
# Sharpe ratio: 0.5588155591643788
# =================================
# Episode 101/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255772.4375
# Final accumulative portfolio value: 2.557724375
# Sharpe ratio: 0.5587891178791731
# =================================
# Episode 102/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255762.96875
# Final accumulative portfolio value: 2.5576296875
# Sharpe ratio: 0.5587335127998196
# =================================
# Episode 103/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255753.5
# Final accumulative portfolio value: 2.557535
# Sharpe ratio: 0.5586751463981267
# =================================
# Episode 104/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255756.046875
# Final accumulative portfolio value: 2.55756046875
# Sharpe ratio: 0.5586388766802115
# =================================
# Episode 105/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255756.25
# Final accumulative portfolio value: 2.5575625
# Sharpe ratio: 0.5585974942615329
# =================================
# Episode 106/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255743.71875
# Final accumulative portfolio value: 2.5574371875
# Sharpe ratio: 0.5585337886894741
# =================================
# Episode 107/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255750.5
# Final accumulative portfolio value: 2.557505
# Sharpe ratio: 0.5585027100936288
# =================================
# Episode 108/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255758.265625
# Final accumulative portfolio value: 2.55758265625
# Sharpe ratio: 0.5584715495575255
# =================================
# Episode 109/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255738.09375
# Final accumulative portfolio value: 2.5573809375
# Sharpe ratio: 0.5583955526493065
# =================================
# Episode 110/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255737.390625
# Final accumulative portfolio value: 2.55737390625
# Sharpe ratio: 0.5583485736169528
# =================================
# Episode 111/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255740.21875
# Final accumulative portfolio value: 2.5574021875
# Sharpe ratio: 0.5583053533752151
# =================================
# Episode 112/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255736.421875
# Final accumulative portfolio value: 2.55736421875
# Sharpe ratio: 0.5582477185649548
# =================================
# Episode 113/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255729.609375
# Final accumulative portfolio value: 2.55729609375
# Sharpe ratio: 0.5581853035131348
# =================================
# Episode 114/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255715.28125
# Final accumulative portfolio value: 2.5571528125
# Sharpe ratio: 0.5581049782564549
# =================================
# Episode 115/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255734.5625
# Final accumulative portfolio value: 2.557345625
# Sharpe ratio: 0.5580853597312769
# =================================
# Episode 116/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255713.609375
# Final accumulative portfolio value: 2.55713609375
# Sharpe ratio: 0.5579908336322973
# =================================
# Episode 117/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255699.84375
# Final accumulative portfolio value: 2.5569984375
# Sharpe ratio: 0.5579093843982547
# =================================
# Episode 118/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255718.109375
# Final accumulative portfolio value: 2.55718109375
# Sharpe ratio: 0.5578822133537508
# =================================
# Episode 119/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255708.09375
# Final accumulative portfolio value: 2.5570809375
# Sharpe ratio: 0.5578025392063619
# =================================
# Episode 120/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255680.296875
# Final accumulative portfolio value: 2.55680296875
# Sharpe ratio: 0.5576871553475853
# =================================
# Episode 121/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255666.890625
# Final accumulative portfolio value: 2.55666890625
# Sharpe ratio: 0.557597863637218
# =================================
# Episode 122/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255671.078125
# Final accumulative portfolio value: 2.55671078125
# Sharpe ratio: 0.5575362388489519
# =================================
# Episode 123/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255652.734375
# Final accumulative portfolio value: 2.55652734375
# Sharpe ratio: 0.5574314398826825
# =================================
# Episode 124/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255647.296875
# Final accumulative portfolio value: 2.55647296875
# Sharpe ratio: 0.557348461631688
# =================================
# Episode 125/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255634.5
# Final accumulative portfolio value: 2.556345
# Sharpe ratio: 0.5572491129667752
# =================================
# Episode 126/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255611.0
# Final accumulative portfolio value: 2.55611
# Sharpe ratio: 0.5571367235776692
# =================================
# Episode 127/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255601.875
# Final accumulative portfolio value: 2.55601875
# Sharpe ratio: 0.5570482203316537
# =================================
# Episode 128/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255586.828125
# Final accumulative portfolio value: 2.55586828125
# Sharpe ratio: 0.5569409924100306
# =================================
# Episode 129/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255572.015625
# Final accumulative portfolio value: 2.55572015625
# Sharpe ratio: 0.5568317087094564
# =================================
# Episode 130/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255550.4375
# Final accumulative portfolio value: 2.555504375
# Sharpe ratio: 0.5567058634235429
# =================================
# Episode 131/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255524.40625
# Final accumulative portfolio value: 2.5552440625
# Sharpe ratio: 0.5565683636429185
# =================================
# Episode 132/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255511.8125
# Final accumulative portfolio value: 2.555118125
# Sharpe ratio: 0.5564530093941537
# =================================
# Episode 133/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255476.859375
# Final accumulative portfolio value: 2.55476859375
# Sharpe ratio: 0.5562936890170421
# =================================
# Episode 134/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255449.5
# Final accumulative portfolio value: 2.554495
# Sharpe ratio: 0.5561444380155015
# =================================
# Episode 135/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255434.890625
# Final accumulative portfolio value: 2.55434890625
# Sharpe ratio: 0.5560149323760678
# =================================
# Episode 136/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255401.03125
# Final accumulative portfolio value: 2.5540103125
# Sharpe ratio: 0.5558477371668981
# =================================
# Episode 137/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255371.328125
# Final accumulative portfolio value: 2.55371328125
# Sharpe ratio: 0.5556843138651778
# =================================
# Episode 138/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255339.125
# Final accumulative portfolio value: 2.55339125
# Sharpe ratio: 0.555510616095062
# =================================
# Episode 139/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255307.59375
# Final accumulative portfolio value: 2.5530759375
# Sharpe ratio: 0.5553374017447058
# =================================
# Episode 140/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255258.234375
# Final accumulative portfolio value: 2.55258234375
# Sharpe ratio: 0.555126143371862
# =================================
# Episode 141/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255227.90625
# Final accumulative portfolio value: 2.5522790625
# Sharpe ratio: 0.5549500582403881
# =================================
# Episode 142/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255184.109375
# Final accumulative portfolio value: 2.55184109375
# Sharpe ratio: 0.5547431302837728
# =================================
# Episode 143/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255132.078125
# Final accumulative portfolio value: 2.55132078125
# Sharpe ratio: 0.5545158189287817
# =================================
# Episode 144/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255065.296875
# Final accumulative portfolio value: 2.55065296875
# Sharpe ratio: 0.554257338521157
# =================================
# Episode 145/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 255012.0625
# Final accumulative portfolio value: 2.550120625
# Sharpe ratio: 0.5540173927175301
# =================================
# Episode 146/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 254950.359375
# Final accumulative portfolio value: 2.54950359375
# Sharpe ratio: 0.5537599241611487
# =================================
# Episode 147/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 254891.78125
# Final accumulative portfolio value: 2.5489178125
# Sharpe ratio: 0.5535091500187773
# =================================
# Episode 148/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 254828.59375
# Final accumulative portfolio value: 2.5482859375
# Sharpe ratio: 0.5532608479735854
# =================================
# Episode 149/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 254757.375
# Final accumulative portfolio value: 2.54757375
# Sharpe ratio: 0.5529797178435235
# =================================
# Episode 150/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 254691.90625
# Final accumulative portfolio value: 2.5469190625
# Sharpe ratio: 0.5527009848328286
# =================================
# Episode 151/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 254602.59375
# Final accumulative portfolio value: 2.5460259375
# Sharpe ratio: 0.5523752048761079
# =================================
# Episode 152/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 254533.453125
# Final accumulative portfolio value: 2.54533453125
# Sharpe ratio: 0.5520811647394595
# =================================
# Episode 153/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 254440.015625
# Final accumulative portfolio value: 2.54440015625
# Sharpe ratio: 0.5517381334539371
# =================================
# Episode 154/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 254337.84375
# Final accumulative portfolio value: 2.5433784375
# Sharpe ratio: 0.5513922853519045
# =================================
# Episode 155/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 254251.078125
# Final accumulative portfolio value: 2.54251078125
# Sharpe ratio: 0.551060159194762
# =================================
# Episode 156/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 254144.171875
# Final accumulative portfolio value: 2.54144171875
# Sharpe ratio: 0.5506824381369719
# =================================
# Episode 157/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 254020.921875
# Final accumulative portfolio value: 2.54020921875
# Sharpe ratio: 0.5502701640485145
# =================================
# Episode 158/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 253900.296875
# Final accumulative portfolio value: 2.53900296875
# Sharpe ratio: 0.5498578571322149
# =================================
# Episode 159/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 253776.515625
# Final accumulative portfolio value: 2.53776515625
# Sharpe ratio: 0.5494354610119834
# =================================
# Episode 160/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 253653.953125
# Final accumulative portfolio value: 2.53653953125
# Sharpe ratio: 0.549010214601349
# =================================
# Episode 161/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 253504.09375
# Final accumulative portfolio value: 2.5350409375
# Sharpe ratio: 0.548534122272787
# =================================
# Episode 162/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 253364.921875
# Final accumulative portfolio value: 2.53364921875
# Sharpe ratio: 0.5480700969766319
# =================================
# Episode 163/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 253200.65625
# Final accumulative portfolio value: 2.5320065625
# Sharpe ratio: 0.5475597947657384
# =================================
# Episode 164/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 253044.796875
# Final accumulative portfolio value: 2.53044796875
# Sharpe ratio: 0.5470593371014022
# =================================
# Episode 165/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 252871.5
# Final accumulative portfolio value: 2.528715
# Sharpe ratio: 0.546523689701861
# =================================
# Episode 166/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 252682.796875
# Final accumulative portfolio value: 2.52682796875
# Sharpe ratio: 0.5459562402180238
# =================================
# Episode 167/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 252496.15625
# Final accumulative portfolio value: 2.5249615625
# Sharpe ratio: 0.545390984993285
# =================================
# Episode 168/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 252307.15625
# Final accumulative portfolio value: 2.5230715625
# Sharpe ratio: 0.5448178022401867
# =================================
# Episode 169/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 252091.03125
# Final accumulative portfolio value: 2.5209103125
# Sharpe ratio: 0.5441933787820092
# =================================
# Episode 170/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 251874.546875
# Final accumulative portfolio value: 2.51874546875
# Sharpe ratio: 0.543564723137246
# =================================
# Episode 171/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 251636.875
# Final accumulative portfolio value: 2.51636875
# Sharpe ratio: 0.542898537607723
# =================================
# Episode 172/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 251403.09375
# Final accumulative portfolio value: 2.5140309375
# Sharpe ratio: 0.5422348423151359
# =================================
# Episode 173/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 251153.875
# Final accumulative portfolio value: 2.51153875
# Sharpe ratio: 0.5415418625248354
# =================================
# Episode 174/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 250880.734375
# Final accumulative portfolio value: 2.50880734375
# Sharpe ratio: 0.5408053625694896
# =================================
# Episode 175/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 250622.953125
# Final accumulative portfolio value: 2.50622953125
# Sharpe ratio: 0.5400932670417541
# =================================
# Episode 176/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 250330.703125
# Final accumulative portfolio value: 2.50330703125
# Sharpe ratio: 0.5393188960397226
# =================================
# Episode 177/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 250047.203125
# Final accumulative portfolio value: 2.50047203125
# Sharpe ratio: 0.5385611951614605
# =================================
# Episode 178/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 249732.03125
# Final accumulative portfolio value: 2.4973203125
# Sharpe ratio: 0.5377443585484335
# =================================
# Episode 179/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 249425.46875
# Final accumulative portfolio value: 2.4942546875
# Sharpe ratio: 0.5369398077237008
# =================================
# Episode 180/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 249091.625
# Final accumulative portfolio value: 2.49091625
# Sharpe ratio: 0.5360871789134797
# =================================
# Episode 181/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 248758.75
# Final accumulative portfolio value: 2.4875875
# Sharpe ratio: 0.5352360275193564
# =================================
# Episode 182/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 248395.3125
# Final accumulative portfolio value: 2.483953125
# Sharpe ratio: 0.5343268077751406
# =================================
# Episode 183/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 248041.3125
# Final accumulative portfolio value: 2.480413125
# Sharpe ratio: 0.5334310059552524
# =================================
# Episode 184/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 247664.609375
# Final accumulative portfolio value: 2.47664609375
# Sharpe ratio: 0.5324915865163398
# =================================
# Episode 185/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 247283.4375
# Final accumulative portfolio value: 2.472834375
# Sharpe ratio: 0.5315398597784714
# =================================
# Episode 186/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 246885.984375
# Final accumulative portfolio value: 2.46885984375
# Sharpe ratio: 0.5305550677185819
# =================================
# Episode 187/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 246465.59375
# Final accumulative portfolio value: 2.4646559375
# Sharpe ratio: 0.529521187179146
# =================================
# Episode 188/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 246053.9375
# Final accumulative portfolio value: 2.460539375
# Sharpe ratio: 0.5284958799325821
# =================================
# Episode 189/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 245616.25
# Final accumulative portfolio value: 2.4561625
# Sharpe ratio: 0.5274139693586719
# =================================
# Episode 190/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 245163.234375
# Final accumulative portfolio value: 2.45163234375
# Sharpe ratio: 0.526292543548162
# =================================
# Episode 191/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 244694.0
# Final accumulative portfolio value: 2.44694
# Sharpe ratio: 0.5251292190425582
# =================================
# Episode 192/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 244215.34375
# Final accumulative portfolio value: 2.4421534375
# Sharpe ratio: 0.5239334526481885
# =================================
# Episode 193/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 243735.609375
# Final accumulative portfolio value: 2.43735609375
# Sharpe ratio: 0.5227178434752993
# =================================
# Episode 194/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 243222.140625
# Final accumulative portfolio value: 2.43222140625
# Sharpe ratio: 0.5214194638179697
# =================================
# Episode 195/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 242702.140625
# Final accumulative portfolio value: 2.42702140625
# Sharpe ratio: 0.5200900028145846
# =================================
# Episode 196/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 242170.390625
# Final accumulative portfolio value: 2.42170390625
# Sharpe ratio: 0.5187152712171904
# =================================
# Episode 197/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 241613.546875
# Final accumulative portfolio value: 2.41613546875
# Sharpe ratio: 0.517267330626328
# =================================
# Episode 198/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 241062.484375
# Final accumulative portfolio value: 2.41062484375
# Sharpe ratio: 0.5158021111805703
# =================================
# Episode 199/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 240498.8125
# Final accumulative portfolio value: 2.404988125
# Sharpe ratio: 0.5142833320346992
# =================================
# Episode 200/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 239914.0625
# Final accumulative portfolio value: 2.399140625
# Sharpe ratio: 0.5126955449112043
# =================================
# Episode 201/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 239329.0
# Final accumulative portfolio value: 2.39329
# Sharpe ratio: 0.5110760933350852
# =================================
# Episode 202/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 238747.515625
# Final accumulative portfolio value: 2.38747515625
# Sharpe ratio: 0.5094309341523382
# =================================
# Episode 203/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 238152.3125
# Final accumulative portfolio value: 2.381523125
# Sharpe ratio: 0.5077290875183641
# =================================
# Episode 204/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 237557.953125
# Final accumulative portfolio value: 2.37557953125
# Sharpe ratio: 0.5060006571046944
# =================================
# Episode 205/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 236959.765625
# Final accumulative portfolio value: 2.36959765625
# Sharpe ratio: 0.5042356296330941
# =================================
# Episode 206/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 236371.703125
# ...
# =================================
# Episode 933/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225287.40625
# Final accumulative portfolio value: 2.2528740625
# Sharpe ratio: 0.45920579535582223
# =================================
# Episode 934/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225281.375
# Final accumulative portfolio value: 2.25281375
# Sharpe ratio: 0.45919498842443723
# =================================
# Episode 935/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225271.546875
# Final accumulative portfolio value: 2.25271546875
# Sharpe ratio: 0.4591791254235147
# =================================
# Episode 936/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225271.203125
# Final accumulative portfolio value: 2.25271203125
# Sharpe ratio: 0.4591787029161225
# =================================
# Episode 937/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225271.328125
# Final accumulative portfolio value: 2.25271328125
# Sharpe ratio: 0.4591790060273111
# =================================
# Episode 938/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225304.0
# Final accumulative portfolio value: 2.25304
# Sharpe ratio: 0.4592341331914264
# =================================
# Episode 939/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225316.5625
# Final accumulative portfolio value: 2.253165625
# Sharpe ratio: 0.45925424735205533
# =================================
# Episode 940/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225295.375
# Final accumulative portfolio value: 2.25295375
# Sharpe ratio: 0.4592200748177266
# =================================
# Episode 941/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225278.265625
# Final accumulative portfolio value: 2.25278265625
# Sharpe ratio: 0.45919071756165475
# =================================
# Episode 942/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225296.265625
# Final accumulative portfolio value: 2.25296265625
# Sharpe ratio: 0.45922059637091744
# =================================
# Episode 943/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225309.28125
# Final accumulative portfolio value: 2.2530928125
# Sharpe ratio: 0.45924309618602593
# =================================
# Episode 944/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225291.34375
# Final accumulative portfolio value: 2.2529134375
# Sharpe ratio: 0.45921311338745313
# =================================
# Episode 945/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225272.578125
# Final accumulative portfolio value: 2.25272578125
# Sharpe ratio: 0.45918139072798153
# =================================
# Episode 946/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225302.4375
# Final accumulative portfolio value: 2.253024375
# Sharpe ratio: 0.4592313337522706
# =================================
# Episode 947/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225301.359375
# Final accumulative portfolio value: 2.25301359375
# Sharpe ratio: 0.4592298413970938
# =================================
# Episode 948/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225290.859375
# Final accumulative portfolio value: 2.25290859375
# Sharpe ratio: 0.459211664533681
# =================================
# Episode 949/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225273.8125
# Final accumulative portfolio value: 2.252738125
# Sharpe ratio: 0.4591831831162318
# =================================
# Episode 950/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225288.140625
# Final accumulative portfolio value: 2.25288140625
# Sharpe ratio: 0.45920686737363
# =================================
# Episode 951/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225305.421875
# Final accumulative portfolio value: 2.25305421875
# Sharpe ratio: 0.4592356702026511
# =================================
# Episode 952/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225291.421875
# Final accumulative portfolio value: 2.25291421875
# Sharpe ratio: 0.45921321781389757
# =================================
# Episode 953/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225279.734375
# Final accumulative portfolio value: 2.25279734375
# Sharpe ratio: 0.4591936595839041
# =================================
# Episode 954/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225266.96875
# Final accumulative portfolio value: 2.2526696875
# Sharpe ratio: 0.45917149563428844
# =================================
# Episode 955/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225288.359375
# Final accumulative portfolio value: 2.25288359375
# Sharpe ratio: 0.4592087020570229
# =================================
# Episode 956/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225300.765625
# Final accumulative portfolio value: 2.25300765625
# Sharpe ratio: 0.45922886861052903
# =================================
# Episode 957/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225282.484375
# Final accumulative portfolio value: 2.25282484375
# Sharpe ratio: 0.4591979432883777
# =================================
# Episode 958/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225254.265625
# Final accumulative portfolio value: 2.25254265625
# Sharpe ratio: 0.45915019275095864
# =================================
# Episode 959/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225289.359375
# Final accumulative portfolio value: 2.25289359375
# Sharpe ratio: 0.4592085280588246
# =================================
# Episode 960/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225268.609375
# Final accumulative portfolio value: 2.25268609375
# Sharpe ratio: 0.4591747713994587
# =================================
# Episode 961/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225240.609375
# Final accumulative portfolio value: 2.25240609375
# Sharpe ratio: 0.459127172753974
# =================================
# Episode 962/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225276.921875
# Final accumulative portfolio value: 2.25276921875
# Sharpe ratio: 0.45918873890874173
# =================================
# Episode 963/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225256.234375
# Final accumulative portfolio value: 2.25256234375
# Sharpe ratio: 0.4591536171026277
# =================================
# Episode 964/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225260.703125
# Final accumulative portfolio value: 2.25260703125
# Sharpe ratio: 0.45916097553568247
# =================================
# Episode 965/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225257.640625
# Final accumulative portfolio value: 2.25257640625
# Sharpe ratio: 0.4591561763958066
# =================================
# Episode 966/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225256.859375
# Final accumulative portfolio value: 2.25256859375
# Sharpe ratio: 0.45915523748850184
# =================================
# Episode 967/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225256.265625
# Final accumulative portfolio value: 2.25256265625
# Sharpe ratio: 0.4591537488167731
# =================================
# Episode 968/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225255.484375
# Final accumulative portfolio value: 2.25255484375
# Sharpe ratio: 0.4591522200232597
# =================================
# Episode 969/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225266.03125
# Final accumulative portfolio value: 2.2526603125
# Sharpe ratio: 0.4591700039660164
# =================================
# Episode 970/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225258.484375
# Final accumulative portfolio value: 2.25258484375
# Sharpe ratio: 0.45915694318965483
# =================================
# Episode 971/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225272.921875
# Final accumulative portfolio value: 2.25272921875
# Sharpe ratio: 0.459182441035078
# =================================
# Episode 972/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225246.34375
# Final accumulative portfolio value: 2.2524634375
# Sharpe ratio: 0.459136100288862
# =================================
# Episode 973/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225244.984375
# Final accumulative portfolio value: 2.25244984375
# Sharpe ratio: 0.4591348423865944
# =================================
# Episode 974/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225251.546875
# Final accumulative portfolio value: 2.25251546875
# Sharpe ratio: 0.45914535633238646
# =================================
# Episode 975/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225265.75
# Final accumulative portfolio value: 2.2526575
# Sharpe ratio: 0.45916916254059076
# =================================
# Episode 976/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225281.703125
# Final accumulative portfolio value: 2.25281703125
# Sharpe ratio: 0.45919588287868957
# =================================
# Episode 977/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225275.65625
# Final accumulative portfolio value: 2.2527565625
# Sharpe ratio: 0.4591869358793901
# =================================
# Episode 978/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225273.859375
# Final accumulative portfolio value: 2.25273859375
# Sharpe ratio: 0.4591829325202391
# =================================
# Episode 979/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225285.28125
# Final accumulative portfolio value: 2.2528528125
# Sharpe ratio: 0.4592019030908512
# =================================
# Episode 980/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225245.234375
# Final accumulative portfolio value: 2.25245234375
# Sharpe ratio: 0.4591347843984777
# =================================
# Episode 981/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225242.0
# Final accumulative portfolio value: 2.25242
# Sharpe ratio: 0.45913012770943734
# =================================
# Episode 982/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225260.0
# Final accumulative portfolio value: 2.2526
# Sharpe ratio: 0.45916031800494356
# =================================
# Episode 983/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225277.59375
# Final accumulative portfolio value: 2.2527759375
# Sharpe ratio: 0.4591889118527092
# =================================
# Episode 984/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225261.453125
# Final accumulative portfolio value: 2.25261453125
# Sharpe ratio: 0.45916246129062493
# =================================
# Episode 985/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225272.515625
# Final accumulative portfolio value: 2.25272515625
# Sharpe ratio: 0.459180890967304
# =================================
# Episode 986/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225257.8125
# Final accumulative portfolio value: 2.252578125
# Sharpe ratio: 0.45915717682282525
# =================================
# Episode 987/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225257.484375
# Final accumulative portfolio value: 2.25257484375
# Sharpe ratio: 0.4591557417595245
# =================================
# Episode 988/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225252.828125
# Final accumulative portfolio value: 2.25252828125
# Sharpe ratio: 0.4591476111903582
# =================================
# Episode 989/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225247.53125
# Final accumulative portfolio value: 2.2524753125
# Sharpe ratio: 0.4591396020954344
# =================================
# Episode 990/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225260.390625
# Final accumulative portfolio value: 2.25260390625
# Sharpe ratio: 0.459160632800525
# =================================
# Episode 991/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225291.234375
# Final accumulative portfolio value: 2.25291234375
# Sharpe ratio: 0.45921228404390535
# =================================
# Episode 992/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225323.921875
# Final accumulative portfolio value: 2.25323921875
# Sharpe ratio: 0.4592672738235576
# =================================
# Episode 993/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225330.546875
# Final accumulative portfolio value: 2.25330546875
# Sharpe ratio: 0.4592779086217792
# =================================
# Episode 994/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225314.15625
# Final accumulative portfolio value: 2.2531415625
# Sharpe ratio: 0.45925108745316995
# =================================
# Episode 995/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225303.8125
# Final accumulative portfolio value: 2.253038125
# Sharpe ratio: 0.4592332449240399
# =================================
# Episode 996/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225304.765625
# Final accumulative portfolio value: 2.25304765625
# Sharpe ratio: 0.45923500661503436
# =================================
# Episode 997/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225294.34375
# Final accumulative portfolio value: 2.2529434375
# Sharpe ratio: 0.4592167634724958
# =================================
# Episode 998/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225282.4375
# Final accumulative portfolio value: 2.252824375
# Sharpe ratio: 0.4591974428865876
# =================================
# Episode 999/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225300.6875
# Final accumulative portfolio value: 2.253006875
# Sharpe ratio: 0.4592276071418592
# =================================
# Episode 1000/1000
# =================================
# Initial portfolio value:100000
# Final portfolio value: 225322.296875
# Final accumulative portfolio value: 2.25322296875
# Sharpe ratio: 0.45926530002985366
# =================================

# %% [markdown]
# **Error: TypeError: index is not a valid DatetimeIndex or PeriodIndex**
#
# https://developer.baidu.com/article/detail.html?id=2793537
#
# ```
# df.index = pd.to_datetime(df.index)
# ```
# 最终原因是df_metrics定义之后缺少下面一句：
# ```
# metrics_df.set_index("date", inplace=True)
# ```

# %% [markdown]
# ### Save Model

# %%
model_name =f"policy_EIIE_episodes{EPISODES}.pt"
torch.save(algo.target_policy.state_dict(), model_name)

# %% [markdown]
# ## Test Model

# %% [markdown]
# ### Define test periods
# In this work, we are going to use three annual test periods: the year of 2020, 2021 and 2022. To get data from Yahoo Finance, we do just like in the training data.

# %%
portfolio_2020_raw_df = YahooDownloader(start_date = '2020-01-01',
                                end_date = '2020-12-31',
                                ticker_list = TOP_BRL).fetch_data()
portfolio_2021_raw_df = YahooDownloader(start_date = '2021-01-01',
                                end_date = '2021-12-31',
                                ticker_list = TOP_BRL).fetch_data()
portfolio_2022_raw_df = YahooDownloader(start_date = '2022-01-01',
                                end_date = '2022-12-31',
                                ticker_list = TOP_BRL).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (2480, 8)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (2470, 8)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (2500, 8)

# %%
portfolio_2020_raw_df.groupby("tic").count()
# Out:
#           date  open  high  low  close  volume  day
# tic
# ABEV3.SA   248   248   248  248    248     248  248
# BBAS3.SA   248   248   248  248    248     248  248
# BBDC4.SA   248   248   248  248    248     248  248
# ITUB4.SA   248   248   248  248    248     248  248
# LREN3.SA   248   248   248  248    248     248  248
# PETR4.SA   248   248   248  248    248     248  248
# PRIO3.SA   248   248   248  248    248     248  248
# RENT3.SA   248   248   248  248    248     248  248
# VALE3.SA   248   248   248  248    248     248  248
# WEGE3.SA   248   248   248  248    248     248  248

# %%
portfolio_2021_raw_df.groupby("tic").count()
# Out:
#           date  open  high  low  close  volume  day
# tic
# ABEV3.SA   247   247   247  247    247     247  247
# BBAS3.SA   247   247   247  247    247     247  247
# BBDC4.SA   247   247   247  247    247     247  247
# ITUB4.SA   247   247   247  247    247     247  247
# LREN3.SA   247   247   247  247    247     247  247
# PETR4.SA   247   247   247  247    247     247  247
# PRIO3.SA   247   247   247  247    247     247  247
# RENT3.SA   247   247   247  247    247     247  247
# VALE3.SA   247   247   247  247    247     247  247
# WEGE3.SA   247   247   247  247    247     247  247

# %%
portfolio_2022_raw_df.groupby("tic").count()
# Out:
#           date  open  high  low  close  volume  day
# tic
# ABEV3.SA   250   250   250  250    250     250  250
# BBAS3.SA   250   250   250  250    250     250  250
# BBDC4.SA   250   250   250  250    250     250  250
# ITUB4.SA   250   250   250  250    250     250  250
# LREN3.SA   250   250   250  250    250     250  250
# PETR4.SA   250   250   250  250    250     250  250
# PRIO3.SA   250   250   250  250    250     250  250
# RENT3.SA   250   250   250  250    250     250  250
# VALE3.SA   250   250   250  250    250     250  250
# WEGE3.SA   250   250   250  250    250     250  250

# %% [markdown]
# ### Instantiate different environments
#
# Since we have three different periods of time, we need three different environments instantiated to simulate them.

# %%
df_portfolio_2020 = portfolio_2020_raw_df[["date", "tic", "close", "high", "low"]]
df_portfolio_2021 = portfolio_2021_raw_df[["date", "tic", "close", "high", "low"]]
df_portfolio_2022 = portfolio_2022_raw_df[["date", "tic", "close", "high", "low"]]

# %%
environment_2020 = PortfolioOptimizationEnv(
    df_portfolio_2020,
    initial_amount=100000,
    comission_fee_pct=0.0025,
    time_window=50,
    features=["close", "high", "low"]
)

environment_2021 = PortfolioOptimizationEnv(
    df_portfolio_2021,
    initial_amount=100000,
    comission_fee_pct=0.0025,
    time_window=50,
    features=["close", "high", "low"]
)

environment_2022 = PortfolioOptimizationEnv(
    df_portfolio_2022,
    initial_amount=100000,
    comission_fee_pct=0.0025,
    time_window=50,
    features=["close", "high", "low"]
)
# Out:
# Normalizing ['close', 'high', 'low'] by previous time...
# Normalizing ['close', 'high', 'low'] by previous time...
# Normalizing ['close', 'high', 'low'] by previous time...

# %% [markdown]
# ### Test EIIE architecture
# Now, we can test the EIIE architecture in the three different test periods. It's important no note three things:
# - In this code, we load the saved policy even though it's not necessary just to show how to save and load your model;
# - It's important to reset the environment before an episode and to create a new PVM (portfolio vector memory) for each case
# - The neural network is expecting a batch of data, so it's necessary to create an additional dimension to the input data if it's a single item.

# %%
EIIE_results = {
    "training": environment._asset_memory["final"],
    "2020": {},
    "2021": {},
    "2022": {}
}

policy = GradientPolicy()
policy.load_state_dict(torch.load(model_name))
policy = policy.to(device)
# Out:
# /var/folders/dv/ly5hp_ms3bd9753868lg6c5w0000gn/T/ipykernel_57233/2601244132.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   policy.load_state_dict(torch.load(model_name))

# %%
# 2020
done = False
obs = environment_2020.reset()
print(f'environment_2020.episode_length:{environment_2020.episode_length}')
pvm = PVM(environment_2020.episode_length)
while not done:
    last_action = pvm.retrieve()
    obs_batch = np.expand_dims(obs, axis=0)
    last_action_batch = np.expand_dims(last_action, axis=0)
    action = policy(obs_batch, last_action_batch)
    pvm.add(action)
    obs, _, done, _ = environment_2020.step(action)
EIIE_results["2020"]["value"] = environment_2020._asset_memory["final"]
# Out:
# environment_2020.episode_length:199
# =================================
# Initial portfolio value:100000
# Final portfolio value: 165839.625
# Final accumulative portfolio value: 1.65839625
# Sharpe ratio: 1.621419846757534
# =================================

# %%
EIIE_results
# Out:
# {'training': [100000,
#   99911.98,
#   99866.13,
#   100414.01,
#   99890.14,
#   101352.57,
#   101090.97,
#   101120.67,
#   101372.95,
#   101206.16,
#   100440.15,
#   100604.12,
#   101069.22,
#   103412.02,
#   103316.57,
#   103068.75,
#   103168.625,
#   102668.69,
#   102184.2,
#   101418.89,
#   101308.98,
#   99832.34,
#   100042.484,
#   99516.94,
#   99084.87,
#   100684.45,
#   101610.0,
#   100714.31,
#   101344.82,
#   100184.19,
#   99624.91,
#   100244.62,
#   99359.76,
#   97638.15,
#   95756.38,
#   97368.02,
#   98913.766,
#   99707.836,
#   99088.51,
#   97500.766,
#   98309.29,
#   97534.96,
#   97022.73,
#   96849.44,
#   95912.164,
#   95305.74,
#   93911.6,
#   94922.52,
#   94863.445,
#   95130.234,
#   97099.914,
#   97442.83,
#   97139.76,
#   96113.76,
#   95997.41,
#   94840.37,
#   96060.35,
#   95426.17,
#   94814.8,
#   95256.7,
#   95632.25,
#   96035.83,
#   97389.51,
#   96243.56,
#   97105.64,
#   95920.64,
#   96388.89,
#   97110.945,
#   97247.66,
#   95727.03,
#   96995.625,
#   97863.44,
#   97146.86,
#   99337.14,
#   99939.59,
#   100053.414,
#   100343.28,
#   101049.89,
#   101732.6,
#   102675.56,
#   102986.68,
#   105208.33,
#   104653.66,
#   105703.11,
#   103768.53,
#   103052.93,
#   103396.86,
#   99734.82,
#   98598.66,
#   99272.734,
#   97598.31,
#   96860.875,
#   98047.95,
#   100601.01,
#   99102.55,
#   97962.28,
#   97308.72,
#   96031.89,
#   95451.98,
#   96281.78,
#   95544.195,
#   93167.82,
#   93228.14,
#   91101.11,
#   91270.266,
#   92219.08,
#   99564.22,
#   98364.81,
#   99212.16,
#   98900.72,
#   95753.07,
#   98012.836,
#   99388.23,
#   98103.71,
#   95068.23,
#   96769.484,
#   95364.64,
#   91560.484,
#   91454.45,
#   90609.16,
#   88633.13,
#   85761.055,
#   89528.77,
#   89918.23,
#   89309.64,
#   90809.39,
#   91998.18,
#   92800.875,
#   91027.44,
#   90146.47,
#   89692.45,
#   91263.67,
#   88545.9,
#   88639.14,
#   89648.59,
#   87246.88,
#   87481.016,
#   87344.77,
#   87580.266,
#   89799.89,
#   94590.37,
#   93015.97,
#   92391.14,
#   92148.266,
#   91359.58,
#   89332.88,
#   88077.484,
#   87059.72,
#   88365.42,
#   87713.15,
#   87997.25,
#   84400.89,
#   85122.73,
#   83665.4,
#   82554.336,
#   80785.17,
#   74927.8,
#   78359.39,
#   80992.87,
#   81001.266,
#   82289.63,
#   82159.78,
#   82997.766,
#   82058.75,
#   82896.13,
#   81362.63,
#   79398.016,
#   78295.06,
#   79306.11,
#   80611.75,
#   80322.78,
#   80345.08,
#   79505.03,
#   78480.8,
#   78781.695,
#   79391.95,
#   78603.766,
#   78601.195,
#   80105.77,
#   84213.67,
#   84018.55,
#   83825.89,
#   83207.46,
#   81405.516,
#   80524.15,
#   78610.664,
#   78839.12,
#   82941.4,
#   84033.33,
#   83780.05,
#   83859.98,
#   82434.03,
#   84421.74,
#   82664.58,
#   83340.63,
#   85170.55,
#   87737.15,
#   87667.99,
#   88120.56,
#   86938.25,
#   87900.68,
#   86840.24,
#   87403.44,
#   87049.4,
#   86701.03,
#   86099.125,
#   85518.5,
#   85233.09,
#   84377.97,
#   83380.195,
#   81676.35,
#   81006.46,
#   83111.84,
#   80562.555,
#   81493.195,
#   80614.5,
#   84196.484,
#   85912.91,
#   85486.72,
#   85850.0,
#   86266.67,
#   86648.59,
#   86087.55,
#   84148.83,
#   ...],
#  '2020': {'value': [100000,
#    84481.62,
#    85662.61,
#    79090.88,
#    73672.2,
#    83065.82,
#    80182.586,
#    81958.695,
#    82506.82,
#    91067.34,
#    89515.414,
#    89624.83,
#    89104.58,
#    83692.89,
#    85879.54,
#    88097.1,
#    89248.84,
#    98243.26,
#    96646.95,
#    101111.484,
#    96415.695,
#    98816.53,
#    94992.984,
#    97013.87,
#    95589.65,
#    93378.03,
#    94741.35,
#   120423.35,
#   122214.26,
#   119941.0,
#   120538.734,
#   122318.516,
#   119210.51,
#   119178.984,
#   119529.55,
#   119711.76,
#   120097.0,
#   123503.31,
#   122931.54,
#   123475.71,
#   125717.87,
#   125987.84,
#   126680.94,
#   126192.27,
#   126797.95,
#   126588.11,
#   127661.72,
#   129640.2,
#   128775.13,
#   132330.44,
#   130889.9,
#   132573.9,
#   127751.055,
#   124181.39,
#   124549.81,
#   123892.44,
#   126568.914,
#   128591.234,
#   128068.39,
#   134866.42,
#   135922.34,
#   138739.94,
#   137588.25,
#   135342.48,
#   139482.38,
#   139571.27,
#   141763.62,
#   140398.64,
#   142774.06,
#   144698.98,
#   145686.47,
#   145862.31,
#   146890.98,
#   146856.11,
#   146149.78,
#   148128.17,
#   148474.73,
#   150110.28,
#   150591.19,
#   150128.16,
#   150123.7,
#   150562.83,
#   151771.17,
#   153371.95,
#   151686.58,
#   153896.08,
#   155844.48,
#   156762.03,
#   152389.53,
#   153601.25,
#   154463.19,
#   158695.98,
#   159663.6,
#   159572.31]}

# %%
# 2021
done = False
obs = environment_2021.reset()
pvm = PVM(environment_2021.episode_length)
while not done:
    last_action = pvm.retrieve()
    obs_batch = np.expand_dims(obs, axis=0)
    last_action_batch = np.expand_dims(last_action, axis=0)
    action = policy(obs_batch, last_action_batch)
    pvm.add(action)
    observation, _, done, _ = environment_2021.step(action)
EIIE_results["2021"]["value"] = environment_2021._asset_memory["final"]
# Out:
# =================================
# Initial portfolio value:100000
# Final portfolio value: 66354.5703125
# Final accumulative portfolio value: 0.663545703125
# Sharpe ratio: -1.2812754870994327
# =================================

# %%
# 2022
done = False
obs = environment_2022.reset()
pvm = PVM(environment_2022.episode_length)
while not done:
    last_action = pvm.retrieve()
    obs_batch = np.expand_dims(obs, axis=0)
    last_action_batch = np.expand_dims(last_action, axis=0)
    action = policy(obs_batch, last_action_batch)
    pvm.add(action)
    obs, _, done, _ = environment_2022.step(action)
EIIE_results["2022"]["value"] = environment_2022._asset_memory["final"]
# Out:
# =================================
# Initial portfolio value:100000
# Final portfolio value: 146638.234375
# Final accumulative portfolio value: 1.46638234375
# Sharpe ratio: 1.5195122385406996
# =================================

# %% [markdown]
# ### Test Uniform Buy and Hold
#
# For comparison, we will also test the performance of a uniform buy and hold strategy. In this strategy, the portfolio has no remaining cash and the same percentage of money is allocated in each asset.

# %%
UBAH_results = {
    "train": {},
    "2020": {},
    "2021": {},
    "2022": {}
}

# train period
terminated = False
environment.reset()
while not terminated:
    action = [0] + [1/PORTFOLIO_SIZE] * PORTFOLIO_SIZE
    _, _, terminated, _ = environment.step(action)
UBAH_results["train"]["value"] = environment._asset_memory["final"]

# 2020
terminated = False
environment_2020.reset()
while not terminated:
    action = [0] + [1/PORTFOLIO_SIZE] * PORTFOLIO_SIZE
    _, _, terminated, _ = environment_2020.step(action)
UBAH_results["2020"]["value"] = environment_2020._asset_memory["final"]
# Out:
# =================================
# Initial portfolio value:100000
# Final portfolio value: 284375.125
# Final accumulative portfolio value: 2.84375125
# Sharpe ratio: 0.6257457375213986
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 159442.453125
# Final accumulative portfolio value: 1.59442453125
# Sharpe ratio: 1.5637494626568484
# =================================

# %%
# 2021
terminated = False
environment_2021.reset()
while not terminated:
    action = [0] + [1/PORTFOLIO_SIZE] * PORTFOLIO_SIZE
    _, _, terminated, _ = environment_2021.step(action)
UBAH_results["2021"]["value"] = environment_2021._asset_memory["final"]
# Out:
# =================================
# Initial portfolio value:100000
# Final portfolio value: 94797.3359375
# Final accumulative portfolio value: 0.947973359375
# Sharpe ratio: -0.31029966370170436
# =================================

# %%
# 2022
terminated = False
environment_2022.reset()
while not terminated:
    action = [0] + [1/PORTFOLIO_SIZE] * PORTFOLIO_SIZE
    _, _, terminated, _ = environment_2022.step(action)
UBAH_results["2022"]["value"] = environment_2022._asset_memory["final"]
# Out:
# =================================
# Initial portfolio value:100000
# Final portfolio value: 106890.6015625
# Final accumulative portfolio value: 1.068906015625
# Sharpe ratio: 0.4834435801893833
# =================================

# %% [markdown]
# ### Plot graphics

# %%
UBAH_results["train"]["value"]
# Out:
# [100000,
#  99939.88,
#  99933.45,
#  100484.31,
#  99944.66,
#  101414.06,
#  101189.05,
#  101192.39,
#  101375.57,
#  101189.23,
#  100405.41,
#  100583.516,
#  101113.02,
#  103453.06,
#  103355.33,
#  103109.266,
#  103172.516,
#  102671.08,
#  102182.664,
#  101400.8,
#  101291.72,
#  99820.62,
#  100043.03,
#  99544.25,
#  99074.98,
#  100667.484,
#  101605.78,
#  100754.16,
#  101390.01,
#  100272.125,
#  99686.734,
#  100341.92,
#  99479.055,
#  97748.984,
#  95839.39,
#  97468.414,
#  99022.42,
#  99871.76,
#  99237.484,
#  97605.0,
#  98413.93,
#  97606.76,
#  97059.79,
#  96905.12,
#  95977.305,
#  95332.77,
#  93932.69,
#  94975.65,
#  94930.93,
#  95207.73,
#  97221.46,
#  97592.586,
#  97283.7,
#  96235.93,
#  96112.37,
#  94954.36,
#  96203.914,
#  95562.62,
#  94989.266,
#  95725.914,
#  96488.4,
#  95515.03,
#  95230.64,
#  95248.92,
#  95665.64,
#  95033.695,
#  93864.836,
#  95213.23,
#  95405.8,
#  95723.11,
#  95064.875,
#  95594.5,
#  97617.51,
#  98093.39,
#  97571.016,
#  98975.15,
#  99810.74,
#  98965.59,
#  100028.805,
#  98498.78,
#  96274.55,
#  95399.69,
#  95570.164,
#  96669.64,
#  95370.625,
#  93939.86,
#  93971.234,
#  94487.34,
#  94279.73,
#  96159.53,
#  95820.664,
#  94384.984,
#  93012.67,
#  92047.26,
#  92271.984,
#  93328.78,
#  92606.94,
#  90858.04,
#  87736.46,
#  85663.38,
#  81739.7,
#  81201.54,
#  83026.99,
#  84196.19,
#  86332.17,
#  86566.33,
#  87036.8,
#  86713.95,
#  85027.984,
#  83673.266,
#  85132.266,
#  83719.5,
#  84603.125,
#  84298.31,
#  83983.195,
#  85515.734,
#  87014.79,
#  89006.33,
#  92463.336,
#  92173.86,
#  89736.82,
#  87692.91,
#  91570.17,
#  90687.13,
#  87676.82,
#  89837.51,
#  89684.01,
#  90500.2,
#  90170.75,
#  89710.81,
#  90420.12,
#  90633.96,
#  86698.555,
#  85008.5,
#  85456.31,
#  87482.74,
#  86940.79,
#  86612.984,
#  85206.57,
#  83690.67,
#  82328.57,
#  82185.18,
#  84301.26,
#  86363.33,
#  84405.61,
#  86034.95,
#  87210.734,
#  87855.43,
#  86778.48,
#  86029.07,
#  87383.99,
#  87808.836,
#  87426.414,
#  88043.45,
#  88616.61,
#  89330.375,
#  89599.22,
#  90979.66,
#  90383.51,
#  87625.984,
#  90324.234,
#  89821.34,
#  90793.12,
#  90685.91,
#  88328.7,
#  87932.54,
#  88050.086,
#  88459.234,
#  88106.66,
#  88288.21,
#  87426.016,
#  85278.805,
#  85015.22,
#  83874.5,
#  84151.01,
#  83739.45,
#  84868.875,
#  85124.37,
#  85751.72,
#  88944.19,
#  90122.484,
#  89732.61,
#  90025.34,
#  89968.55,
#  89301.086,
#  88236.87,
#  88494.06,
#  87939.35,
#  87604.91,
#  86627.66,
#  86225.07,
#  85543.71,
#  85603.03,
#  86488.13,
#  86955.76,
#  87771.69,
#  87653.15,
#  87425.42,
#  87701.61,
#  87061.89,
#  87177.73,
#  88135.14,
#  87810.375,
#  85578.01,
#  86481.18,
#  86155.98,
#  86962.05,
#  86263.85,
#  86968.27,
#  86780.32,
#  86510.445,
#  87235.0,
#  88556.586,
#  90180.11,
#  90630.81,
#  90791.445,
#  90520.33,
#  91818.06,
#  92187.75,
#  90469.28,
#  91759.4,
#  92053.4,
#  92413.68,
#  91622.64,
#  93062.125,
#  92980.805,
#  94136.516,
#  93422.33,
#  92079.33,
#  92857.24,
#  94384.375,
#  94804.055,
#  93698.17,
#  96083.19,
#  95732.99,
#  96137.56,
#  95973.83,
#  96193.78,
#  97792.15,
#  98287.305,
#  99214.07,
#  99188.11,
#  97592.45,
#  97501.984,
#  99293.53,
#  99609.72,
#  99114.97,
#  99703.92,
#  100940.266,
#  100316.21,
#  100314.71,
#  100938.49,
#  99959.53,
#  99889.79,
#  99160.375,
#  97743.8,
#  98508.84,
#  99984.78,
#  99404.94,
#  97157.305,
#  98224.234,
#  97578.11,
#  97952.586,
#  96529.84,
#  95081.22,
#  93514.26,
#  93645.87,
#  92820.78,
#  93481.02,
#  93893.39,
#  93338.73,
#  93007.39,
#  93136.35,
#  93679.92,
#  94152.17,
#  92661.414,
#  92194.14,
#  92336.984,
#  90410.64,
#  91897.43,
#  92539.836,
#  92402.19,
#  93068.65,
#  91537.945,
#  90389.57,
#  90984.78,
#  89328.25,
#  90114.61,
#  88525.31,
#  87365.4,
#  86485.805,
#  85985.7,
#  85021.99,
#  82939.62,
#  83821.64,
#  85400.664,
#  83579.57,
#  83071.81,
#  82391.55,
#  84354.25,
#  85135.445,
#  83357.984,
#  83593.12,
#  83190.805,
#  82537.46,
#  82131.625,
#  81101.07,
#  82672.984,
#  83570.68,
#  82924.73,
#  83380.2,
#  83468.88,
#  83908.836,
#  84026.44,
#  85716.484,
#  87490.55,
#  86540.23,
#  84887.72,
#  83123.14,
#  82668.33,
#  81717.06,
#  80869.766,
#  83132.8,
#  83213.5,
#  83878.11,
#  84447.77,
#  85290.62,
#  84215.22,
#  84111.45,
#  82459.19,
#  80989.266,
#  82584.95,
#  82057.24,
#  81706.24,
#  81299.24,
#  82847.484,
#  83017.46,
#  81485.5,
#  81396.05,
#  81609.26,
#  81238.49,
#  83464.49,
#  85592.11,
#  86607.06,
#  85216.66,
#  84250.89,
#  86127.375,
#  85854.77,
#  88387.04,
#  87600.89,
#  88218.5,
#  87486.66,
#  87821.266,
#  86920.73,
#  86104.89,
#  86768.9,
#  87266.086,
#  86786.766,
#  88427.516,
#  87316.42,
#  87790.1,
#  87499.36,
#  88468.0,
#  87775.234,
#  87606.516,
#  87459.72,
#  89788.46,
#  87642.13,
#  87257.64,
#  86942.84,
#  88002.24,
#  88934.15,
#  88534.16,
#  90564.82,
#  91064.875,
#  93380.29,
#  94080.94,
#  94364.51,
#  93612.5,
#  92790.84,
#  93576.2,
#  92540.82,
#  93459.016,
#  90679.45,
#  91524.12,
#  90449.125,
#  90535.83,
#  91484.86,
#  91553.33,
#  90205.38,
#  90630.37,
#  89895.64,
#  91289.84,
#  90569.16,
#  90331.914,
#  90849.02,
#  93367.09,
#  92752.03,
#  92256.58,
#  93342.59,
#  92972.65,
#  91609.375,
#  92342.84,
#  92793.67,
#  92229.984,
#  92568.586,
#  92800.914,
#  93219.86,
#  92609.055,
#  93890.53,
#  94687.13,
#  95130.836,
#  94126.54,
#  91732.945,
#  92534.734,
#  91750.69,
#  92505.64,
#  91930.23,
#  92404.34,
#  93291.625,
#  92396.17,
#  93069.59,
#  93509.67,
#  94214.16,
#  92924.37,
#  94027.61,
#  94881.34,
#  95275.23,
#  95426.664,
#  95146.18,
#  95300.305,
#  95552.91,
#  96398.69,
#  97505.86,
#  97548.875,
#  97742.89,
#  97923.234,
#  98328.94,
#  98602.02,
#  99216.27,
#  100480.0,
#  99218.94,
#  99771.65,
#  99222.13,
#  98886.22,
#  100319.02,
#  100887.086,
#  103065.77,
#  102526.09,
#  101937.18,
#  100903.03,
#  101856.0,
#  100764.836,
#  101232.72,
#  101231.17,
#  100058.88,
#  100610.12,
#  100725.47,
#  100216.87,
#  99682.65,
#  99473.24,
#  100520.6,
#  99844.945,
#  97682.29,
#  97738.445,
#  96693.11,
#  96431.02,
#  96421.68,
#  95529.76,
#  95472.57,
#  95097.74,
#  94483.71,
#  95655.25,
#  95020.83,
#  95073.2,
#  95253.305,
#  95059.586,
#  94959.57,
#  93304.38,
#  93675.89,
#  94507.65,
#  93051.38,
#  93541.66,
#  93048.04,
#  94147.68,
#  94668.66,
#  94789.805,
#  95403.86,
#  96833.59,
#  96366.77,
#  96803.99,
#  96553.125,
#  96040.42,
#  95466.15,
#  95731.71,
#  94618.64,
#  94616.53,
#  94790.695,
#  94688.6,
#  94592.93,
#  94415.77,
#  93555.27,
#  93822.52,
#  94587.086,
#  94120.414,
#  94117.35,
#  94038.39,
#  94735.39,
#  93832.71,
#  94983.13,
#  95339.64,
#  96795.16,
#  97153.62,
#  95831.055,
#  94643.38,
#  94106.086,
#  93164.86,
#  92822.04,
#  92222.54,
#  93572.9,
#  94075.34,
#  95346.46,
#  96116.125,
#  95283.66,
#  94829.58,
#  94479.99,
#  95547.65,
#  95850.03,
#  94971.34,
#  95634.94,
#  96938.7,
#  97050.125,
#  96894.07,
#  96861.78,
#  95511.125,
#  80467.87,
#  80505.24,
#  80019.586,
#  79682.76,
#  79879.17,
#  80736.04,
#  79884.43,
#  79191.66,
#  79444.9,
#  77850.43,
#  77661.516,
#  76881.43,
#  77881.24,
#  76824.42,
#  76476.28,
#  76819.945,
#  77871.22,
#  78167.48,
#  78888.77,
#  80113.69,
#  80662.164,
#  81393.61,
#  81168.96,
#  83262.445,
#  83456.234,
#  83968.13,
#  83834.94,
#  85139.086,
#  85823.15,
#  85726.8,
#  87753.1,
#  85695.16,
#  85151.19,
#  85264.49,
#  86809.44,
#  85597.7,
#  85117.49,
#  85438.734,
#  86373.13,
#  86218.234,
#  86105.73,
#  85036.01,
#  84098.195,
#  84165.234,
#  83257.03,
#  83000.45,
#  84452.2,
#  85642.21,
#  85522.42,
#  86538.07,
#  86246.29,
#  86150.96,
#  87087.125,
#  86805.67,
#  88228.17,
#  87987.82,
#  87327.84,
#  86335.62,
#  85590.82,
#  84781.17,
#  85803.805,
#  85137.3,
#  85482.47,
#  84864.95,
#  86741.71,
#  85107.69,
#  84453.78,
#  84250.48,
#  84596.336,
#  84874.72,
#  87116.2,
#  87244.03,
#  88644.45,
#  90368.516,
#  89644.85,
#  89394.12,
#  90042.29,
#  89944.055,
#  91204.85,
#  91018.17,
#  90682.44,
#  90117.06,
#  90098.9,
#  89654.98,
#  89965.125,
#  90407.375,
#  89742.31,
#  88721.25,
#  90452.305,
#  89947.83,
#  89730.29,
#  90495.914,
#  90309.57,
#  92317.08,
#  93842.516,
#  93807.06,
#  92824.91,
#  95356.26,
#  95320.02,
#  96473.58,
#  95915.69,
#  97248.555,
#  97529.77,
#  97181.98,
#  96282.66,
#  95436.83,
#  94320.72,
#  94705.91,
#  95117.52,
#  96496.28,
#  95316.95,
#  96190.31,
#  95002.305,
#  95479.984,
#  96212.125,
#  96383.734,
#  94863.5,
#  96147.36,
#  97000.7,
#  96256.516,
#  98486.02,
#  99099.266,
#  99223.586,
#  99513.43,
#  100227.484,
#  100924.53,
#  101850.66,
#  102181.234,
#  104383.76,
#  103820.83,
#  104881.3,
#  102914.484,
#  102193.195,
#  102529.734,
#  98804.29,
#  97674.17,
#  98347.08,
#  96642.34,
#  95914.484,
#  97112.39,
#  99707.125,
#  98192.29,
#  97029.26,
#  96352.53,
#  95069.4,
#  94473.7,
#  95289.46,
#  94557.16,
#  92148.03,
#  92206.516,
#  90069.08,
#  90232.93,
#  91183.98,
#  98608.18,
#  97408.336,
#  98263.7,
#  97952.5,
#  94777.31,
#  97076.53,
#  98486.45,
#  97197.41,
#  94145.25,
#  95840.8,
#  94435.79,
#  90558.51,
#  90451.89,
#  89601.695,
#  87569.766,
#  84720.734,
#  88458.19,
#  88829.43,
#  88219.21,
#  89742.81,
#  90922.734,
#  91716.23,
#  89920.24,
#  89026.42,
#  88561.67,
#  90148.984,
#  87414.62,
#  87501.92,
#  88538.22,
#  86114.016,
#  86361.61,
#  86218.49,
#  86432.89,
#  88683.85,
#  93500.97,
#  91898.84,
#  91271.48,
#  91022.766,
#  90226.484,
#  88180.4,
#  86924.19,
#  85896.836,
#  87204.445,
#  86548.91,
#  86826.88,
#  83225.01,
#  83951.9,
#  82452.664,
#  81305.93,
#  79554.97,
#  73684.8,
#  77138.24,
#  79787.32,
#  79769.24,
#  81074.72,
#  80941.805,
#  81784.234,
#  80826.74,
#  81672.08,
#  80121.516,
#  78136.5,
#  77031.02,
#  78059.3,
#  79376.73,
#  79079.586,
#  79105.72,
#  78259.63,
#  77221.37,
#  77510.4,
#  78125.195,
#  77332.27,
#  77322.26,
#  78829.04,
#  82968.5,
#  82772.71,
#  82563.71,
#  81957.195,
#  80119.97,
#  79227.414,
#  77274.58,
#  77522.37,
#  81635.625,
#  82735.66,
#  82476.484,
#  82559.78,
#  81119.9,
#  83125.56,
#  81342.34,
#  82011.18,
#  83865.98,
#  86470.0,
#  86395.56,
#  86840.766,
#  85661.625,
#  86618.57,
#  85565.195,
#  86149.56,
#  85815.016,
#  85490.18,
#  84872.336,
#  84267.1,
#  83974.2,
#  83126.71,
#  82125.805,
#  80416.35,
#  79737.94,
#  81848.625,
#  79276.53,
#  80214.29,
#  79359.89,
#  82964.055,
#  84673.37,
#  84229.95,
#  84599.016,
#  85043.33,
#  85428.96,
#  84874.055,
#  82923.28,
#  ...]

# %%
EIIE_results["training"]
# Out:
# [100000,
#  99911.98,
#  99866.13,
#  100414.01,
#  99890.14,
#  101352.57,
#  101090.97,
#  101120.67,
#  101372.95,
#  101206.16,
#  100440.15,
#  100604.12,
#  101069.22,
#  103412.02,
#  103316.57,
#  103068.75,
#  103168.625,
#  102668.69,
#  102184.2,
#  101418.89,
#  101308.98,
#  99832.34,
#  100042.484,
#  99516.94,
#  99084.87,
#  100684.45,
#  101610.0,
#  100714.31,
#  101344.82,
#  100184.19,
#  99624.91,
#  100244.62,
#  99359.76,
#  97638.15,
#  95756.38,
#  97368.02,
#  98913.766,
#  99707.836,
#  99088.51,
#  97500.766,
#  98309.29,
#  97534.96,
#  97022.73,
#  96849.44,
#  95912.164,
#  95305.74,
#  93911.6,
#  94922.52,
#  94863.445,
#  95130.234,
#  97099.914,
#  97442.83,
#  97139.76,
#  96113.76,
#  95997.41,
#  94840.37,
#  96060.35,
#  95426.17,
#  94814.8,
#  95583.734,
#  96328.04,
#  95362.8,
#  95068.39,
#  95087.5,
#  95517.03,
#  94883.55,
#  93751.39,
#  95069.97,
#  95260.89,
#  95591.125,
#  94941.14,
#  95467.836,
#  97495.53,
#  97962.195,
#  97417.07,
#  98798.56,
#  99629.15,
#  98803.92,
#  99897.3,
#  98379.516,
#  96195.52,
#  95298.24,
#  95427.87,
#  96568.49,
#  95278.64,
#  93906.62,
#  93982.21,
#  94500.94,
#  94289.05,
#  96134.28,
#  95722.36,
#  94266.29,
#  92931.54,
#  91957.805,
#  92178.125,
#  93214.984,
#  92508.48,
#  90814.97,
#  87761.484,
#  85674.91,
#  81794.664,
#  81217.37,
#  83047.65,
#  84184.78,
#  86278.72,
#  86527.03,
#  86991.766,
#  86710.67,
#  85052.24,
#  83737.39,
#  85142.79,
#  83755.28,
#  84623.05,
#  84325.14,
#  83997.23,
#  85510.21,
#  87020.21,
#  89005.51,
#  92410.766,
#  92131.32,
#  89741.47,
#  87754.875,
#  91576.336,
#  90694.05,
#  87746.98,
#  89901.44,
#  89751.47,
#  90588.4,
#  90277.47,
#  89803.09,
#  90506.875,
#  90720.65,
#  86861.11,
#  85173.625,
#  85598.31,
#  87594.49,
#  87063.54,
#  86739.38,
#  85359.88,
#  83895.97,
#  82561.16,
#  82418.88,
#  84497.984,
#  86571.45,
#  84651.125,
#  86268.05,
#  87402.484,
#  88039.87,
#  86976.734,
#  86241.44,
#  87553.64,
#  87978.266,
#  87590.56,
#  88199.47,
#  88761.69,
#  89479.66,
#  89729.59,
#  91101.73,
#  90510.766,
#  87765.49,
#  90425.21,
#  89952.96,
#  90888.87,
#  90803.39,
#  88476.67,
#  88071.445,
#  88188.02,
#  88611.78,
#  88248.08,
#  88431.63,
#  87563.336,
#  85424.13,
#  85142.96,
#  84019.47,
#  84261.95,
#  83876.195,
#  84992.21,
#  85224.78,
#  85829.55,
#  89015.54,
#  90183.86,
#  89779.7,
#  90072.266,
#  90016.0,
#  89332.09,
#  88267.91,
#  88534.5,
#  87995.945,
#  87688.484,
#  86720.445,
#  86322.875,
#  85666.64,
#  85724.57,
#  86620.67,
#  87123.875,
#  87933.49,
#  87792.7,
#  87555.195,
#  87838.9,
#  87211.93,
#  87359.94,
#  88281.14,
#  87985.43,
#  85792.62,
#  86712.06,
#  86368.22,
#  87156.56,
#  86464.49,
#  87155.164,
#  86966.74,
#  86711.78,
#  87421.945,
#  88721.62,
#  90305.16,
#  90752.45,
#  90908.945,
#  90641.48,
#  91936.8,
#  92324.78,
#  90617.32,
#  91870.66,
#  92180.27,
#  92520.99,
#  91729.23,
#  93145.484,
#  93103.91,
#  94273.445,
#  93542.6,
#  92189.25,
#  92944.39,
#  94472.914,
#  94854.734,
#  93753.93,
#  96100.125,
#  95746.81,
#  96144.664,
#  96000.13,
#  96198.17,
#  97754.41,
#  98241.16,
#  99146.95,
#  99163.85,
#  97595.36,
#  97491.555,
#  99276.05,
#  99587.266,
#  99081.625,
#  99649.1,
#  100881.02,
#  100289.9,
#  100299.01,
#  100895.18,
#  99929.18,
#  99853.555,
#  99140.445,
#  97748.09,
#  98497.63,
#  99965.85,
#  99414.58,
#  97205.18,
#  98252.65,
#  97604.516,
#  97969.3,
#  96575.164,
#  95125.06,
#  93581.46,
#  93711.5,
#  92917.8,
#  93576.984,
#  93982.125,
#  93432.0,
#  93105.44,
#  93272.32,
#  93817.805,
#  94286.55,
#  92825.02,
#  92344.04,
#  92493.77,
#  90587.77,
#  92029.95,
#  92681.48,
#  92546.51,
#  93197.086,
#  91693.55,
#  90561.92,
#  91160.055,
#  89544.664,
#  90325.63,
#  88773.63,
#  87640.914,
#  86753.375,
#  86268.31,
#  85316.45,
#  83270.766,
#  84136.875,
#  85687.19,
#  83903.6,
#  83410.67,
#  82733.37,
#  84672.3,
#  85446.45,
#  83700.516,
#  83925.63,
#  83556.14,
#  82899.93,
#  82485.484,
#  81459.7,
#  83028.914,
#  83915.61,
#  83271.02,
#  83705.8,
#  83786.36,
#  84190.375,
#  84289.49,
#  85947.125,
#  87667.6,
#  86748.62,
#  85129.945,
#  83408.305,
#  82948.07,
#  82025.57,
#  81195.59,
#  83419.445,
#  83513.87,
#  84154.39,
#  84705.2,
#  85533.72,
#  84448.23,
#  84356.586,
#  82743.46,
#  81313.984,
#  82885.77,
#  82336.97,
#  81992.484,
#  81589.516,
#  83113.73,
#  83270.7,
#  81767.56,
#  81662.23,
#  81866.25,
#  81486.164,
#  83713.73,
#  85811.414,
#  86818.625,
#  85433.984,
#  84484.484,
#  86344.39,
#  86070.19,
#  88587.67,
#  87816.625,
#  88419.555,
#  87702.625,
#  88009.41,
#  87163.984,
#  86389.78,
#  87019.85,
#  87490.52,
#  87014.97,
#  88641.13,
#  87552.945,
#  88021.305,
#  87728.25,
#  88686.15,
#  88005.41,
#  87839.64,
#  87726.375,
#  90011.44,
#  87896.26,
#  87536.83,
#  87260.32,
#  88353.484,
#  89273.34,
#  88854.66,
#  90890.59,
#  91367.336,
#  93673.83,
#  94349.71,
#  94652.21,
#  93918.77,
#  93109.47,
#  93879.016,
#  92877.73,
#  93793.47,
#  91035.08,
#  91880.87,
#  90849.13,
#  90968.85,
#  91887.766,
#  91929.484,
#  90597.89,
#  91026.445,
#  90292.75,
#  91678.38,
#  90956.49,
#  90720.69,
#  91244.31,
#  93717.51,
#  93076.484,
#  92601.125,
#  93674.52,
#  93324.375,
#  91976.48,
#  92703.62,
#  93137.15,
#  92585.7,
#  92934.805,
#  93152.79,
#  93563.484,
#  92960.37,
#  94227.36,
#  95051.805,
#  95478.086,
#  94481.32,
#  92118.2,
#  92897.47,
#  92127.02,
#  92869.945,
#  92378.664,
#  92844.61,
#  93741.766,
#  92862.24,
#  93533.14,
#  93945.08,
#  94648.586,
#  93396.28,
#  94460.875,
#  95325.29,
#  95776.03,
#  95905.56,
#  95649.58,
#  95853.4,
#  96070.8,
#  96882.91,
#  97980.35,
#  98009.36,
#  98255.19,
#  98446.68,
#  98810.5,
#  99051.234,
#  99671.2,
#  100921.06,
#  99663.47,
#  100216.28,
#  99695.836,
#  99372.54,
#  100753.49,
#  101348.45,
#  103551.18,
#  102996.97,
#  102409.33,
#  101335.45,
#  102300.11,
#  101182.09,
#  101664.05,
#  101662.5,
#  100488.25,
#  101056.23,
#  101152.43,
#  100637.18,
#  100093.48,
#  99887.89,
#  100955.54,
#  100289.75,
#  98091.28,
#  98139.32,
#  97104.05,
#  96835.92,
#  96849.77,
#  95927.3,
#  95836.73,
#  95499.4,
#  94872.055,
#  96062.016,
#  95420.57,
#  95489.914,
#  95702.79,
#  95489.59,
#  95400.67,
#  93752.97,
#  94122.04,
#  94950.61,
#  93515.02,
#  93979.5,
#  93475.92,
#  94643.57,
#  95183.2,
#  95278.484,
#  95915.11,
#  97337.03,
#  96848.79,
#  97286.78,
#  97009.05,
#  96496.58,
#  95928.664,
#  96222.586,
#  95080.766,
#  95078.66,
#  95277.34,
#  95155.19,
#  95061.016,
#  94913.44,
#  94065.95,
#  82739.26,
#  82889.51,
#  83002.89,
#  81198.766,
#  81519.45,
#  80689.81,
#  82074.266,
#  82759.71,
#  81702.195,
#  81299.414,
#  81737.84,
#  81363.71,
#  82471.43,
#  80892.75,
#  81252.98,
#  81462.14,
#  80331.53,
#  79475.5,
#  79256.67,
#  79722.23,
#  78550.01,
#  78644.055,
#  79411.984,
#  80187.67,
#  79989.83,
#  81032.71,
#  81824.16,
#  80542.195,
#  81004.586,
#  81418.19,
#  80646.51,
#  79682.984,
#  80201.77,
#  81345.734,
#  81383.375,
#  80894.39,
#  80550.77,
#  80774.37,
#  81621.85,
#  80792.55,
#  80102.266,
#  80360.11,
#  78773.266,
#  78568.47,
#  77793.76,
#  78798.56,
#  77728.92,
#  77405.336,
#  77772.15,
#  78831.18,
#  79124.164,
#  79836.5,
#  81070.04,
#  81608.2,
#  82328.47,
#  82107.05,
#  84171.65,
#  84373.1,
#  84871.93,
#  84743.22,
#  86061.984,
#  86734.33,
#  86646.87,
#  88638.44,
#  86611.016,
#  86089.64,
#  86227.36,
#  87772.055,
#  86547.68,
#  86081.14,
#  86427.94,
#  87351.22,
#  87196.81,
#  87081.49,
#  85999.92,
#  85092.1,
#  85173.09,
#  84273.18,
#  84032.15,
#  85472.68,
#  86632.055,
#  86518.31,
#  87528.77,
#  87272.52,
#  87183.94,
#  88111.19,
#  87832.02,
#  89236.734,
#  88981.36,
#  88336.49,
#  87330.41,
#  86583.984,
#  85792.77,
#  86794.09,
#  86110.28,
#  86465.35,
#  85856.9,
#  87704.79,
#  86085.2,
#  85435.04,
#  85235.55,
#  85590.09,
#  85889.07,
#  88111.08,
#  88243.055,
#  89648.28,
#  91396.74,
#  90665.51,
#  90418.82,
#  91041.6,
#  90954.12,
#  92204.02,
#  92002.66,
#  91673.89,
#  91128.23,
#  91104.53,
#  90672.83,
#  90972.57,
#  91420.89,
#  90763.54,
#  89752.7,
#  91472.7,
#  90966.31,
#  90727.016,
#  91446.92,
#  91272.22,
#  93284.19,
#  94809.805,
#  94742.15,
#  93768.766,
#  96263.23,
#  96215.016,
#  97390.664,
#  96846.984,
#  98183.62,
#  98457.664,
#  98102.875,
#  97238.125,
#  96390.37,
#  95256.7,
#  95632.25,
#  96035.83,
#  97389.51,
#  96243.56,
#  97105.64,
#  95920.64,
#  96388.89,
#  97110.945,
#  97247.66,
#  95727.03,
#  96995.625,
#  97863.44,
#  97146.86,
#  99337.14,
#  99939.59,
#  100053.414,
#  100343.28,
#  101049.89,
#  101732.6,
#  102675.56,
#  102986.68,
#  105208.33,
#  104653.66,
#  105703.11,
#  103768.53,
#  103052.93,
#  103396.86,
#  99734.82,
#  98598.66,
#  99272.734,
#  97598.31,
#  96860.875,
#  98047.95,
#  100601.01,
#  99102.55,
#  97962.28,
#  97308.72,
#  96031.89,
#  95451.98,
#  96281.78,
#  95544.195,
#  93167.82,
#  93228.14,
#  91101.11,
#  91270.266,
#  92219.08,
#  99564.22,
#  98364.81,
#  99212.16,
#  98900.72,
#  95753.07,
#  98012.836,
#  99388.23,
#  98103.71,
#  95068.23,
#  96769.484,
#  95364.64,
#  91560.484,
#  91454.45,
#  90609.16,
#  88633.13,
#  85761.055,
#  89528.77,
#  89918.23,
#  89309.64,
#  90809.39,
#  91998.18,
#  92800.875,
#  91027.44,
#  90146.47,
#  89692.45,
#  91263.67,
#  88545.9,
#  88639.14,
#  89648.59,
#  87246.88,
#  87481.016,
#  87344.77,
#  87580.266,
#  89799.89,
#  94590.37,
#  93015.97,
#  92391.14,
#  92148.266,
#  91359.58,
#  89332.88,
#  88077.484,
#  87059.72,
#  88365.42,
#  87713.15,
#  87997.25,
#  84400.89,
#  85122.73,
#  83665.4,
#  82554.336,
#  80785.17,
#  74927.8,
#  78359.39,
#  80992.87,
#  81001.266,
#  82289.63,
#  82159.78,
#  82997.766,
#  82058.75,
#  82896.13,
#  81362.63,
#  79398.016,
#  78295.06,
#  79306.11,
#  80611.75,
#  80322.78,
#  80345.08,
#  79505.03,
#  78480.8,
#  78781.695,
#  79391.95,
#  78603.766,
#  78601.195,
#  80105.77,
#  84213.67,
#  84018.55,
#  83825.89,
#  83207.46,
#  81405.516,
#  80524.15,
#  78610.664,
#  78839.12,
#  82941.4,
#  84033.33,
#  83780.05,
#  83859.98,
#  82434.03,
#  84421.74,
#  82664.58,
#  83340.63,
#  85170.55,
#  87737.15,
#  87667.99,
#  88120.56,
#  86938.25,
#  87900.68,
#  86840.24,
#  87403.44,
#  87049.4,
#  86701.03,
#  86099.125,
#  85518.5,
#  85233.09,
#  84377.97,
#  83380.195,
#  81676.35,
#  81006.46,
#  83111.84,
#  80562.555,
#  81493.195,
#  80614.5,
#  84196.484,
#  85912.91,
#  85486.72,
#  85850.0,
#  86266.67,
#  86648.59,
#  86087.55,
#  84148.83,
#  ...]

# %%
import matplotlib.pyplot as plt

plt.plot(UBAH_results["train"]["value"], label="Buy and Hold")
plt.plot(EIIE_results["training"], label="EIIE")

plt.xlabel("Days")
plt.ylabel("Portfolio Value")
plt.title(f"Performance in training period episode{EPISODES}")
plt.legend()
plt.savefig(f"results/performance_in_training_episode{EPISODES}.png")
plt.show()

# %%
plt.plot(UBAH_results["2020"]["value"], label="Buy and Hold")
plt.plot(EIIE_results["2020"]["value"], label="EIIE")

plt.xlabel("Days")
plt.ylabel("Portfolio Value")
plt.title(f"Performance in 2020 episode{EPISODES}")
plt.legend()
plt.savefig(f"results/performance_in_2020_episode{EPISODES}.png")
plt.show()

# %%
plt.plot(UBAH_results["2021"]["value"], label="Buy and Hold")
plt.plot(EIIE_results["2021"]["value"], label="EIIE")

plt.xlabel("Days")
plt.ylabel("Portfolio Value")
plt.title(f"Performance in 2021 episode{EPISODES}")
plt.legend()

plt.savefig(f"results/performance_in_2021_episode{EPISODES}.png")
plt.show()

# %%
plt.plot(UBAH_results["2022"]["value"], label="Buy and Hold")
plt.plot(EIIE_results["2022"]["value"], label="EIIE")

plt.xlabel("Days")
plt.ylabel("Portfolio Value")
plt.title(f"Performance in 2022 episode{EPISODES}")
plt.legend()
plt.savefig(f"results/performance_in_2022_episode{EPISODES}.png")
plt.show()
